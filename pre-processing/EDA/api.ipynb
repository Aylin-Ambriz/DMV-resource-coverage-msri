# %%
# ==============================================================================
# STEP 1: INSTALL AND IMPORT NECESSARY TOOLS (LIBRARIES)
# ==============================================================================

# The % symbol means this is a "magic command" - special instructions for Jupyter
# This installs external software packages we need:
# - requests: for sending HTTP requests to Google's servers
# - pandas: for working with spreadsheet-like data (CSV files)
# %pip install requests pandas

# "import" means "bring in tools from external libraries so we can use them"
# Think of this like borrowing specialized calculators from different departments

import requests    # For communicating with Google's API over the internet
import json       # For working with JSON data format (JavaScript Object Notation)
import itertools  # For generating mathematical combinations and permutations
import pandas as pd  # For reading CSV files and working with tabular data
                    # "as pd" means we can write "pd" instead of "pandas" later


# ==============================================================================
# STEP 2: SET UP GOOGLE API CREDENTIALS AND ENDPOINT
# ==============================================================================

# This is like a password that identifies us to Google's servers
# Google gives you this key when you create an account with them
API_KEY = "AIzaSyC1On9XIHa2rQmwBGDdmG5_EDexq0DKWHM" # Replace with your actual API key

# This is the web address (URL) where Google's routing service lives
# It's like a mailing address, but for computer programs
# When we send requests here, Google calculates driving routes for us
url = "https://routes.googleapis.com/directions/v2:computeRoutes"

# ==============================================================================
# STEP 3: LOAD DMV OFFICE DATA FROM CSV FILE
# ==============================================================================

# CSV stands for "Comma Separated Values" - it's like a spreadsheet saved as text
# pd.read_csv() reads the CSV file and creates a "DataFrame" (like a table)
# A DataFrame has rows and columns, just like a spreadsheet in Excel
locations_df = pd.read_csv('output/dmv_offices_details.csv')

# ==============================================================================
# STEP 4: CONVERT SPREADSHEET DATA INTO A LIST OF OFFICE INFORMATION
# ==============================================================================

# We're creating an empty list to store information about each office
# A "list" in programming is like a mathematical sequence: [item1, item2, item3, ...]
office_locations = []

# This is a "for loop" - it repeats the same actions for each row in our spreadsheet
# "iterrows()" goes through each row of the DataFrame one by one
# The underscore "_" means we don't care about the row index number
# "row" is a variable that represents the current row we're looking at
for _, row in locations_df.iterrows():
    
    # For each office, we create a "dictionary" (like a mini-database entry)
    # A dictionary stores key-value pairs: {'key': value, 'another_key': another_value}
    # Think of it like a filing cabinet where each drawer has a label
    office_locations.append({
        'name': row['office_name'],    # Get the office name from this row
        'latitude': row['latitude'],   # Get the latitude coordinate
        'longitude': row['longitude']  # Get the longitude coordinate
    })

# ==============================================================================
# STEP 5: DISPLAY SUMMARY INFORMATION
# ==============================================================================

# len() gives us the length (number of items) in our list
# f"text {variable}" is called an "f-string" - it inserts the variable into the text
print(f"Loaded {len(office_locations)} DMV offices")
print("Sample offices:")

# Show information about the first 5 offices
# [:5] means "take items from position 0 to 4" (the first 5 items)
# enumerate() gives us both the position number (i) and the item (office)
for i, office in enumerate(office_locations[:5]):
    # .4f means "show 4 decimal places for floating point numbers"
    print(f"  {office['name']}: ({office['latitude']:.4f}, {office['longitude']:.4f})")

# ==============================================================================
# STEP 6: GENERATE ALL POSSIBLE OFFICE-TO-OFFICE ROUTE COMBINATIONS
# ==============================================================================

# In mathematics, a "permutation" is an arrangement where order matters
# For example, if we have offices A, B, C, then (A→B) is different from (B→A)
# itertools.permutations(list, 2) gives us all possible pairs where order matters
# This creates every possible route from one office to another office
office_pairs = list(itertools.permutations(office_locations, 2))

# For testing purposes, we only take the first 6 routes
# This prevents us from making 27,722 API calls (which would cost ~$138)
# Comment out this line if you want to calculate ALL possible routes


# Display how many routes we're going to calculate
print(f"\nGenerated {len(office_pairs)} office-to-office routes to calculate")

# Show the first 5 offices again (this line displays the result)
office_locations[:5]  # Show first 5 offices
# Out:
# Requirement already satisfied: requests in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: pandas in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from requests) (2025.7.9)
# Requirement already satisfied: numpy>=1.26.0 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/derekprice/Documents/GitHub/DMV-resource-coverage-msri/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Loaded 167 DMV offices
# Sample offices:
#   Alturas: (41.4919, -120.5498)
#   Arleta: (34.2479, -118.4452)
#   Arvin: (35.2113, -118.8333)
#   Auburn: (38.9070, -121.0827)
#   Bakersfield: (35.3878, -119.0233)
#
# Generated 27722 office-to-office routes to calculate
# [{'name': 'Alturas', 'latitude': 41.4919116, 'longitude': -120.5498434},
#  {'name': 'Arleta', 'latitude': 34.2479119, 'longitude': -118.4452195},
#  {'name': 'Arvin', 'latitude': 35.2112669, 'longitude': -118.8333219},
#  {'name': 'Auburn', 'latitude': 38.9069626, 'longitude': -121.082718},
#  {'name': 'Bakersfield', 'latitude': 35.3878084, 'longitude': -119.0233475}]

# %%
# ==============================================================================
# STEP 7: PREPARE API REQUEST DATA FOR EACH OFFICE PAIR
# ==============================================================================

# We need to create two empty lists:
# 1. request_bodies: contains the data we'll send to Google (API format)
# 2. office_info: contains human-readable office information (for our reference)
request_bodies = []
office_info = []  # Store office info separately

# This loop goes through each office pair (origin → destination)
# Remember: office_pairs contains tuples like (office1, office2)
for origin_office, destination_office in office_pairs:
    
    # Create a dictionary in the exact format Google's API expects
    # This is like filling out a form with very specific fields
    # Google requires nested dictionaries (dictionaries inside dictionaries)
    data = {
      "origin": {                          # Where the journey starts
        "location": {                      # Location information
          "latLng": {                      # Latitude and longitude coordinates
            "latitude": origin_office['latitude'],    # Starting latitude
            "longitude": origin_office['longitude']   # Starting longitude
          }
        }
      },
      "destination": {                     # Where the journey ends
        "location": {                      # Location information
          "latLng": {                      # Latitude and longitude coordinates
            "latitude": destination_office['latitude'],   # Ending latitude
            "longitude": destination_office['longitude']  # Ending longitude
          }
        }
      },
      "travelMode": "DRIVE",               # We want driving directions (not walking/transit)
      # Add other parameters as needed (e.g., routingPreference, departureTime)
    }
    
    # Add this formatted request data to our list
    request_bodies.append(data)
    
    # Store office info separately (same index as request_bodies)
    # This keeps track of which offices correspond to which request
    office_info.append({
        'origin_office': origin_office,
        'destination_office': destination_office
    })

# ==============================================================================
# STEP 8: SET UP HTTP REQUEST HEADERS AND ROBUST PROCESSING
# ==============================================================================

import time
import os
from datetime import datetime
from urllib3.exceptions import ConnectionError as Urllib3ConnectionError
from requests.exceptions import ConnectionError, Timeout, RequestException

# Headers are like the "envelope" information for our API requests
# They tell Google's servers important metadata about our request
headers = {
    "Content-Type": "application/json",    # We're sending JSON data
    "X-Goog-Api-Key": API_KEY,             # Our authentication key
    "X-Goog-FieldMask": "routes.duration,routes.distanceMeters",  # Only return distance and duration
}

# ==============================================================================
# ROBUST PROCESSING CONFIGURATION
# ==============================================================================

# Configuration for robust processing
BATCH_SIZE = 10  # Save progress every 10 requests
MAX_RETRIES = 3  # Try each request up to 3 times
RETRY_DELAY = 5  # Wait 5 seconds between retries
REQUEST_DELAY = 0.5  # Wait 0.5 seconds between requests to avoid rate limiting

# File names for saving progress
PROGRESS_FILE = "dmv_api_progress.json"
RESULTS_FILE = "dmv_office_route_distances.json"
LOG_FILE = "dmv_api_log.txt"

# ==============================================================================
# UTILITY FUNCTIONS
# ==============================================================================

def log_message(message):
    """Log a message with timestamp to both console and file"""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_entry = f"[{timestamp}] {message}"
    print(log_entry)
    
    # Also write to log file
    with open(LOG_FILE, 'a') as f:
        f.write(log_entry + '\n')

def save_progress(results, completed_indices, failed_indices=None):
    """Save current progress to files"""
    # Save results so far
    with open(RESULTS_FILE, 'w') as f:
        json.dump(results, f, indent=4)
    
    # Save progress tracking
    progress_data = {
        'completed_indices': completed_indices,
        'failed_indices': failed_indices or [],
        'total_requests': len(request_bodies),
        'completed_count': len(completed_indices),
        'failed_count': len(failed_indices) if failed_indices else 0,
        'last_updated': datetime.now().isoformat()
    }
    
    with open(PROGRESS_FILE, 'w') as f:
        json.dump(progress_data, f, indent=4)
    
    log_message(f"Progress saved: {len(completed_indices)} completed, {len(failed_indices) if failed_indices else 0} failed, {len(request_bodies) - len(completed_indices) - (len(failed_indices) if failed_indices else 0)} remaining")

def load_progress():
    """Load previous progress if it exists"""
    if os.path.exists(PROGRESS_FILE) and os.path.exists(RESULTS_FILE):
        try:
            with open(PROGRESS_FILE, 'r') as f:
                progress_data = json.load(f)
            
            with open(RESULTS_FILE, 'r') as f:
                results = json.load(f)
            
            completed_indices = set(progress_data['completed_indices'])
            failed_indices = set(progress_data.get('failed_indices', []))
            
            log_message(f"Resuming from previous session: {len(completed_indices)} completed, {len(failed_indices)} failed")
            log_message(f"Will retry {len(failed_indices)} previously failed requests")
            return results, completed_indices, failed_indices
        except Exception as e:
            log_message(f"Error loading progress: {e}. Starting fresh.")
            return [], set(), set()
    else:
        log_message("Starting fresh session")
        return [], set(), set()

def make_api_request(data, request_index, office_info_item):
    """Make a single API request with retry logic"""
    origin_name = office_info_item['origin_office']['name']
    destination_name = office_info_item['destination_office']['name']
    
    for attempt in range(MAX_RETRIES):
        try:
            log_message(f"Request {request_index + 1}/{len(request_bodies)}: {origin_name} → {destination_name} (attempt {attempt + 1})")
            
            # Make the API request
            response = requests.post(url, json=data, headers=headers, timeout=30)
            
            # Check if the request was successful
            if response.status_code == 200:
                response_data = response.json()
                
                # Check if routes exist and the list is not empty
                if "routes" in response_data and response_data["routes"]:
                    first_route = response_data["routes"][0]
                    distance = first_route.get("distanceMeters")
                    duration = first_route.get("duration")
                    
                    if distance is not None:
                        origin_office = office_info_item['origin_office']
                        destination_office = office_info_item['destination_office']
                        
                        result = {
                            "origin_office_name": origin_office['name'],
                            "origin_latitude": origin_office['latitude'],
                            "origin_longitude": origin_office['longitude'],
                            "destination_office_name": destination_office['name'],
                            "destination_latitude": destination_office['latitude'],
                            "destination_longitude": destination_office['longitude'],
                            "distanceMeters": distance,
                            "duration": duration
                        }
                        
                        log_message(f"  ✅ Success: {distance:,} meters, {duration}")
                        return result
                    else:
                        log_message(f"  ❌ Could not retrieve distance")
                        return None
                else:
                    log_message(f"  ❌ No routes found in response")
                    return None
            else:
                log_message(f"  ❌ Error: Status {response.status_code}")
                if attempt < MAX_RETRIES - 1:
                    log_message(f"  ⏳ Retrying in {RETRY_DELAY} seconds...")
                    time.sleep(RETRY_DELAY)
                continue
                
        except (ConnectionError, Urllib3ConnectionError, Timeout, RequestException) as e:
            log_message(f"  ❌ Network error: {str(e)}")
            if attempt < MAX_RETRIES - 1:
                log_message(f"  ⏳ Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)
            else:
                log_message(f"  ❌ Failed after {MAX_RETRIES} attempts")
                return None
    
    return None

# ==============================================================================
# STEP 9: ROBUST API PROCESSING WITH BATCH SAVING
# ==============================================================================

# Start logging
log_message("Starting robust DMV office route calculation")
log_message(f"Total requests to process: {len(request_bodies)}")
log_message(f"Batch size: {BATCH_SIZE}, Max retries: {MAX_RETRIES}")

# Load any previous progress
results, completed_indices, failed_indices = load_progress()

# Process each request
for i, (data, office_info_item) in enumerate(zip(request_bodies, office_info)):
    
    # Skip if already completed
    if i in completed_indices:
        continue
    
    # Clear from failed indices if we're retrying
    if i in failed_indices:
        failed_indices.remove(i)
        log_message(f"  🔄 Retrying previously failed request {i+1}")
    
    # Make the API request
    result = make_api_request(data, i, office_info_item)
    
    # Only mark as completed and add to results if successful
    if result is not None:
        results.append(result)
        completed_indices.add(i)  # Only mark as completed on success
        
        # Save progress in batches (only count successful requests)
        if len(completed_indices) % BATCH_SIZE == 0:
            save_progress(results, list(completed_indices), list(failed_indices))
    else:
        # Mark as failed but don't mark as completed (will retry next session)
        failed_indices.add(i)
        log_message(f"  ❌ Request {i+1} failed after {MAX_RETRIES} attempts - will retry in next session")
    
    # Rate limiting: wait between requests
    if i < len(request_bodies) - 1:  # Don't wait after the last request
        time.sleep(REQUEST_DELAY)

# ==============================================================================
# STEP 10: FINAL SAVE AND CLEANUP
# ==============================================================================

# Final save
save_progress(results, list(completed_indices), list(failed_indices))

# Clean up progress file only if no failures (so we can retry failed requests)
if len(failed_indices) == 0:
    if os.path.exists(PROGRESS_FILE):
        os.remove(PROGRESS_FILE)
        log_message("Progress file cleaned up (processing complete)")
else:
    log_message(f"Progress file kept for {len(failed_indices)} failed requests - run again to retry")

# ==============================================================================
# STEP 11: DISPLAY SUMMARY OF RESULTS
# ==============================================================================

log_message(f"Results saved to {RESULTS_FILE}")
log_message(f"Total routes calculated: {len(results)}")
log_message(f"Failed routes: {len(failed_indices)}")
log_message(f"Success rate: {len(results)}/{len(request_bodies)} ({len(results)/len(request_bodies)*100:.1f}%)")

# Show an example result if we have any
if results:
    log_message("Sample result:")
    log_message(f"  {results[0]['origin_office_name']} → {results[0]['destination_office_name']}")
    log_message(f"  Distance: {results[0]['distanceMeters']:,} meters")
    log_message(f"  Duration: {results[0]['duration']}")

if len(failed_indices) > 0:
    log_message(f"⚠️  {len(failed_indices)} requests failed after {MAX_RETRIES} attempts each")
    log_message("Run the notebook again to retry failed requests")
    
log_message("Processing complete!")
# Out:
# [2025-07-09 20:51:56] Starting robust DMV office route calculation
# [2025-07-09 20:51:56] Total requests to process: 27722
# [2025-07-09 20:51:56] Batch size: 10, Max retries: 3
# [2025-07-09 20:51:56] Resuming from previous session: 5360 completed, 0 failed
# [2025-07-09 20:51:56] Will retry 0 previously failed requests
# [2025-07-09 20:51:56] Request 5361/27722: Fairfield → Hanford (attempt 1)
# [2025-07-09 20:51:56]   ✅ Success: 368,062 meters, 12563s
# [2025-07-09 20:51:56] Request 5362/27722: Fairfield → Hawthorne (attempt 1)
# [2025-07-09 20:51:56]   ✅ Success: 643,708 meters, 21854s
# [2025-07-09 20:51:57] Request 5363/27722: Fairfield → Hayward (attempt 1)
# [2025-07-09 20:51:57]   ✅ Success: 90,321 meters, 3539s
# [2025-07-09 20:51:58] Request 5364/27722: Fairfield → Hemet (attempt 1)
# [2025-07-09 20:51:58]   ✅ Success: 766,440 meters, 26540s
# [2025-07-09 20:51:59] Request 5365/27722: Fairfield → Hollister (attempt 1)
# [2025-07-09 20:51:59]   ✅ Success: 191,182 meters, 6890s
# [2025-07-09 20:51:59] Request 5366/27722: Fairfield → Hollywood (attempt 1)
# [2025-07-09 20:52:00]   ✅ Success: 622,170 meters, 21038s
# [2025-07-09 20:52:00] Request 5367/27722: Fairfield → Indio (attempt 1)
# [2025-07-09 20:52:01]   ✅ Success: 834,255 meters, 27802s
# [2025-07-09 20:52:01] Request 5368/27722: Fairfield → Jackson (attempt 1)
# [2025-07-09 20:52:01]   ✅ Success: 143,946 meters, 5908s
# [2025-07-09 20:52:02] Request 5369/27722: Fairfield → King City (attempt 1)
# [2025-07-09 20:52:02]   ✅ Success: 288,397 meters, 10032s
# [2025-07-09 20:52:03] Request 5370/27722: Fairfield → Lake Isabella (attempt 1)
# [2025-07-09 20:52:03]   ✅ Success: 651,972 meters, 22354s
# [2025-07-09 20:52:03] Progress saved: 5370 completed, 0 failed, 22352 remaining
# [2025-07-09 20:52:04] Request 5371/27722: Fairfield → Lakeport (attempt 1)
# [2025-07-09 20:52:04]   ✅ Success: 144,224 meters, 7236s
# [2025-07-09 20:52:04] Request 5372/27722: Fairfield → Lancaster (attempt 1)
# [2025-07-09 20:52:05]   ✅ Success: 594,950 meters, 19978s
# [2025-07-09 20:52:05] Request 5373/27722: Fairfield → Lincoln Park (attempt 1)
# [2025-07-09 20:52:05]   ✅ Success: 632,144 meters, 21471s
# [2025-07-09 20:52:06] Request 5374/27722: Fairfield → Lodi (attempt 1)
# [2025-07-09 20:52:06]   ✅ Success: 77,957 meters, 4002s
# [2025-07-09 20:52:07] Request 5375/27722: Fairfield → Lompoc (attempt 1)
# [2025-07-09 20:52:07]   ✅ Success: 507,569 meters, 17361s
# [2025-07-09 20:52:08] Request 5376/27722: Fairfield → Long Beach (attempt 1)
# [2025-07-09 20:52:08]   ✅ Success: 667,382 meters, 22532s
# [2025-07-09 20:52:08] Request 5377/27722: Fairfield → Los Angeles (attempt 1)
# [2025-07-09 20:52:09]   ✅ Success: 637,748 meters, 21636s
# [2025-07-09 20:52:09] Request 5378/27722: Fairfield → Los Banos (attempt 1)
# [2025-07-09 20:52:10]   ✅ Success: 211,199 meters, 7349s
# [2025-07-09 20:52:10] Request 5379/27722: Fairfield → Los Gatos (attempt 1)
# [2025-07-09 20:52:10]   ✅ Success: 134,773 meters, 5047s
# [2025-07-09 20:52:11] Request 5380/27722: Fairfield → Madera (attempt 1)
# [2025-07-09 20:52:11]   ✅ Success: 253,474 meters, 9491s
# [2025-07-09 20:52:11] Progress saved: 5380 completed, 0 failed, 22342 remaining
# [2025-07-09 20:52:12] Request 5381/27722: Fairfield → Manteca (attempt 1)
# [2025-07-09 20:52:12]   ✅ Success: 108,931 meters, 4901s
# [2025-07-09 20:52:12] Request 5382/27722: Fairfield → Mariposa (attempt 1)
# [2025-07-09 20:52:13]   ✅ Success: 259,287 meters, 10282s
# [2025-07-09 20:52:13] Request 5383/27722: Fairfield → Mendota (attempt 1)
# [2025-07-09 20:52:13]   ✅ Success: 273,614 meters, 9577s
# [2025-07-09 20:52:14] Request 5384/27722: Fairfield → Merced (attempt 1)
# [2025-07-09 20:52:14]   ✅ Success: 197,045 meters, 7531s
# [2025-07-09 20:52:15] Request 5385/27722: Fairfield → Modesto (attempt 1)
# [2025-07-09 20:52:15]   ✅ Success: 137,942 meters, 5710s
# [2025-07-09 20:52:15] Request 5386/27722: Fairfield → Montebello (attempt 1)
# [2025-07-09 20:52:16]   ✅ Success: 645,565 meters, 22024s
# [2025-07-09 20:52:16] Request 5387/27722: Fairfield → Mt Shasta (attempt 1)
# [2025-07-09 20:52:17]   ✅ Success: 371,501 meters, 12426s
# [2025-07-09 20:52:17] Request 5388/27722: Fairfield → Napa (attempt 1)
# [2025-07-09 20:52:17]   ✅ Success: 22,450 meters, 1046s
# [2025-07-09 20:52:18] Request 5389/27722: Fairfield → Needles (attempt 1)
# [2025-07-09 20:52:18]   ✅ Success: 911,501 meters, 30756s
# [2025-07-09 20:52:19] Request 5390/27722: Fairfield → Newhall (attempt 1)
# [2025-07-09 20:52:19]   ✅ Success: 583,938 meters, 19622s
# [2025-07-09 20:52:19] Progress saved: 5390 completed, 0 failed, 22332 remaining
# [2025-07-09 20:52:20] Request 5391/27722: Fairfield → Norco (attempt 1)
# [2025-07-09 20:52:20]   ✅ Success: 705,914 meters, 23875s
# [2025-07-09 20:52:21] Request 5392/27722: Fairfield → Novato (attempt 1)
# [2025-07-09 20:52:21]   ✅ Success: 57,518 meters, 2457s
# [2025-07-09 20:52:22] Request 5393/27722: Fairfield → Oakland (attempt 1)
# [2025-07-09 20:52:22]   ✅ Success: 63,038 meters, 2454s
# [2025-07-09 20:52:22] Request 5394/27722: Fairfield → Oceanside (attempt 1)
# [2025-07-09 20:52:23]   ✅ Success: 783,448 meters, 26232s
# [2025-07-09 20:52:23] Request 5395/27722: Fairfield → Oroville (attempt 1)
# [2025-07-09 20:52:23]   ✅ Success: 172,436 meters, 6197s
# [2025-07-09 20:52:24] Request 5396/27722: Fairfield → Oxnard (attempt 1)
# [2025-07-09 20:52:24]   ✅ Success: 631,593 meters, 22250s
# [2025-07-09 20:52:25] Request 5397/27722: Fairfield → Palm Desert (attempt 1)
# [2025-07-09 20:52:25]   ✅ Success: 819,646 meters, 27410s
# [2025-07-09 20:52:25] Request 5398/27722: Fairfield → Palm Springs (attempt 1)
# [2025-07-09 20:52:26]   ✅ Success: 803,270 meters, 27022s
# [2025-07-09 20:52:26] Request 5399/27722: Fairfield → Pasadena (attempt 1)
# [2025-07-09 20:52:27]   ✅ Success: 639,574 meters, 21431s
# [2025-07-09 20:52:27] Request 5400/27722: Fairfield → Paso Robles (attempt 1)
# [2025-07-09 20:52:27]   ✅ Success: 370,859 meters, 12570s
# [2025-07-09 20:52:28] Progress saved: 5400 completed, 0 failed, 22322 remaining
# [2025-07-09 20:52:28] Request 5401/27722: Fairfield → Petaluma (attempt 1)
# [2025-07-09 20:52:28]   ✅ Success: 65,310 meters, 2996s
# [2025-07-09 20:52:29] Request 5402/27722: Fairfield → Pittsburg (attempt 1)
# [2025-07-09 20:52:29]   ✅ Success: 56,038 meters, 2307s
# [2025-07-09 20:52:30] Request 5403/27722: Fairfield → Placerville (attempt 1)
# [2025-07-09 20:52:30]   ✅ Success: 134,811 meters, 4753s
# [2025-07-09 20:52:30] Request 5404/27722: Fairfield → Pleasanton (attempt 1)
# [2025-07-09 20:52:31]   ✅ Success: 76,964 meters, 2937s
# [2025-07-09 20:52:31] Request 5405/27722: Fairfield → Pomona (attempt 1)
# [2025-07-09 20:52:31]   ✅ Success: 676,429 meters, 23046s
# [2025-07-09 20:52:32] Request 5406/27722: Fairfield → Porterville (attempt 1)
# [2025-07-09 20:52:32]   ✅ Success: 398,629 meters, 14891s
# [2025-07-09 20:52:33] Request 5407/27722: Fairfield → Poway (attempt 1)
# [2025-07-09 20:52:33]   ✅ Success: 826,436 meters, 28014s
# [2025-07-09 20:52:34] Request 5408/27722: Fairfield → Quincy (attempt 1)
# [2025-07-09 20:52:34]   ✅ Success: 298,396 meters, 11827s
# [2025-07-09 20:52:34] Request 5409/27722: Fairfield → Rancho Cucamonga (attempt 1)
# [2025-07-09 20:52:35]   ✅ Success: 687,883 meters, 23330s
# [2025-07-09 20:52:35] Request 5410/27722: Fairfield → Rancho San Diego Industry Business Center (attempt 1)
# [2025-07-09 20:52:35]   ✅ Success: 850,344 meters, 28721s
# [2025-07-09 20:52:35] Progress saved: 5410 completed, 0 failed, 22312 remaining
# [2025-07-09 20:52:36] Request 5411/27722: Fairfield → Red Bluff (attempt 1)
# [2025-07-09 20:52:36]   ✅ Success: 228,581 meters, 7561s
# [2025-07-09 20:52:37] Request 5412/27722: Fairfield → Redding (attempt 1)
# [2025-07-09 20:52:37]   ✅ Success: 275,011 meters, 9099s
# [2025-07-09 20:52:37] Request 5413/27722: Fairfield → Redlands (attempt 1)
# [2025-07-09 20:52:38]   ✅ Success: 726,528 meters, 24409s
# [2025-07-09 20:52:38] Request 5414/27722: Fairfield → Redwood City (attempt 1)
# [2025-07-09 20:52:39]   ✅ Success: 110,467 meters, 4383s
# [2025-07-09 20:52:39] Request 5415/27722: Fairfield → Reedley (attempt 1)
# [2025-07-09 20:52:40]   ✅ Success: 326,264 meters, 12287s
# [2025-07-09 20:52:40] Request 5416/27722: Fairfield → Ridgecrest (attempt 1)
# [2025-07-09 20:52:40]   ✅ Success: 650,501 meters, 22081s
# [2025-07-09 20:52:41] Request 5417/27722: Fairfield → Riverside (attempt 1)
# [2025-07-09 20:52:41]   ✅ Success: 720,063 meters, 24402s
# [2025-07-09 20:52:42] Request 5418/27722: Fairfield → Riverside East (attempt 1)
# [2025-07-09 20:52:42]   ✅ Success: 723,019 meters, 24434s
# [2025-07-09 20:52:43] Request 5419/27722: Fairfield → Rocklin (attempt 1)
# [2025-07-09 20:52:43]   ✅ Success: 103,561 meters, 3672s
# [2025-07-09 20:52:43] Request 5420/27722: Fairfield → Roseville (attempt 1)
# [2025-07-09 20:52:43]   ✅ Success: 101,108 meters, 3898s
# [2025-07-09 20:52:44] Progress saved: 5420 completed, 0 failed, 22302 remaining
# [2025-07-09 20:52:44] Request 5421/27722: Fairfield → Sacramento (attempt 1)
# [2025-07-09 20:52:44]   ✅ Success: 72,719 meters, 2782s
# [2025-07-09 20:52:45] Request 5422/27722: Fairfield → Sacramento South (attempt 1)
# [2025-07-09 20:52:45]   ✅ Success: 80,514 meters, 2859s
# [2025-07-09 20:52:46] Request 5423/27722: Fairfield → Salinas (attempt 1)
# [2025-07-09 20:52:46]   ✅ Success: 210,792 meters, 7421s
# [2025-07-09 20:52:46] Request 5424/27722: Fairfield → San Andreas (attempt 1)
# [2025-07-09 20:52:47]   ✅ Success: 144,909 meters, 6488s
# [2025-07-09 20:52:47] Request 5425/27722: Fairfield → San Bernardino (attempt 1)
# [2025-07-09 20:52:48]   ✅ Success: 716,368 meters, 24040s
# [2025-07-09 20:52:48] Request 5426/27722: Fairfield → San Clemente (attempt 1)
# [2025-07-09 20:52:49]   ✅ Success: 736,835 meters, 24818s
# [2025-07-09 20:52:49] Request 5427/27722: Fairfield → San Diego (attempt 1)
# [2025-07-09 20:52:49]   ✅ Success: 830,994 meters, 27785s
# [2025-07-09 20:52:50] Request 5428/27722: Fairfield → San Diego Clairemont (attempt 1)
# [2025-07-09 20:52:50]   ✅ Success: 822,128 meters, 27612s
# [2025-07-09 20:52:51] Request 5429/27722: Fairfield → San Francisco (attempt 1)
# [2025-07-09 20:52:51]   ✅ Success: 74,522 meters, 3335s
# [2025-07-09 20:52:52] Request 5430/27722: Fairfield → San Jose (attempt 1)
# [2025-07-09 20:52:52]   ✅ Success: 127,544 meters, 4710s
# [2025-07-09 20:52:52] Progress saved: 5430 completed, 0 failed, 22292 remaining
# [2025-07-09 20:52:52] Request 5431/27722: Fairfield → San Luis Obispo (attempt 1)
# [2025-07-09 20:52:53]   ✅ Success: 418,309 meters, 14158s
# [2025-07-09 20:52:53] Request 5432/27722: Fairfield → San Marcos (attempt 1)
# [2025-07-09 20:52:54]   ✅ Success: 801,580 meters, 26956s
# [2025-07-09 20:52:54] Request 5433/27722: Fairfield → San Mateo (attempt 1)
# [2025-07-09 20:52:54]   ✅ Success: 97,389 meters, 3793s
# [2025-07-09 20:52:55] Request 5434/27722: Fairfield → San Pedro (attempt 1)
# [2025-07-09 20:52:55]   ✅ Success: 664,545 meters, 22317s
# [2025-07-09 20:52:56] Request 5435/27722: Fairfield → San Ysidro (attempt 1)
# [2025-07-09 20:52:56]   ✅ Success: 857,395 meters, 28738s
# [2025-07-09 20:52:57] Request 5436/27722: Fairfield → Santa Ana (attempt 1)
# [2025-07-09 20:52:57]   ✅ Success: 682,205 meters, 23545s
# [2025-07-09 20:52:57] Request 5437/27722: Fairfield → Santa Barbara (attempt 1)
# [2025-07-09 20:52:58]   ✅ Success: 564,410 meters, 19487s
# [2025-07-09 20:52:58] Request 5438/27722: Fairfield → Santa Clara (attempt 1)
# [2025-07-09 20:52:58]   ✅ Success: 124,041 meters, 5011s
# [2025-07-09 20:52:59] Request 5439/27722: Fairfield → Santa Monica (attempt 1)
# [2025-07-09 20:52:59]   ✅ Success: 629,120 meters, 21147s
# [2025-07-09 20:53:00] Request 5440/27722: Fairfield → Santa Paula (attempt 1)
# [2025-07-09 20:53:00]   ✅ Success: 619,166 meters, 20894s
# [2025-07-09 20:53:00] Progress saved: 5440 completed, 0 failed, 22282 remaining
# [2025-07-09 20:53:01] Request 5441/27722: Fairfield → Santa Rosa (attempt 1)
# [2025-07-09 20:53:01]   ✅ Success: 88,471 meters, 3600s
# [2025-07-09 20:53:01] Request 5442/27722: Fairfield → Santa Teresa (attempt 1)
# [2025-07-09 20:53:02]   ✅ Success: 136,177 meters, 5007s
# [2025-07-09 20:53:02] Request 5443/27722: Fairfield → Seaside (attempt 1)
# [2025-07-09 20:53:02]   ✅ Success: 228,186 meters, 8041s
# [2025-07-09 20:53:03] Request 5444/27722: Fairfield → Shafter (attempt 1)
# [2025-07-09 20:53:03]   ✅ Success: 443,266 meters, 14988s
# [2025-07-09 20:53:04] Request 5445/27722: Fairfield → Simi Valley (attempt 1)
# [2025-07-09 20:53:04]   ✅ Success: 622,568 meters, 20802s
# [2025-07-09 20:53:05] Request 5446/27722: Fairfield → Sonora (attempt 1)
# [2025-07-09 20:53:05]   ✅ Success: 188,859 meters, 8251s
# [2025-07-09 20:53:05] Request 5447/27722: Fairfield → South Lake Tahoe (attempt 1)
# [2025-07-09 20:53:06]   ✅ Success: 231,241 meters, 8946s
# [2025-07-09 20:53:06] Request 5448/27722: Fairfield → Stockton (attempt 1)
# [2025-07-09 20:53:06]   ✅ Success: 88,151 meters, 3949s
# [2025-07-09 20:53:07] Request 5449/27722: Fairfield → Susanville (attempt 1)
# [2025-07-09 20:53:07]   ✅ Success: 366,821 meters, 14573s
# [2025-07-09 20:53:08] Request 5450/27722: Fairfield → Taft (attempt 1)
# [2025-07-09 20:53:08]   ✅ Success: 465,080 meters, 15857s
# [2025-07-09 20:53:08] Progress saved: 5450 completed, 0 failed, 22272 remaining
# [2025-07-09 20:53:08] Request 5451/27722: Fairfield → Temecula (attempt 1)
# [2025-07-09 20:53:09]   ✅ Success: 764,149 meters, 25702s
# [2025-07-09 20:53:09] Request 5452/27722: Fairfield → Thousand Oaks (attempt 1)
# [2025-07-09 20:53:10]   ✅ Success: 645,747 meters, 21536s
# [2025-07-09 20:53:10] Request 5453/27722: Fairfield → Torrance (attempt 1)
# [2025-07-09 20:53:11]   ✅ Success: 653,513 meters, 22145s
# [2025-07-09 20:53:11] Request 5454/27722: Fairfield → Tracy (attempt 1)
# [2025-07-09 20:53:11]   ✅ Success: 106,081 meters, 4261s
# [2025-07-09 20:53:12] Request 5455/27722: Fairfield → Truckee (attempt 1)
# [2025-07-09 20:53:12]   ✅ Success: 228,915 meters, 8201s
# [2025-07-09 20:53:13] Request 5456/27722: Fairfield → Tulare (attempt 1)
# [2025-07-09 20:53:13]   ✅ Success: 359,016 meters, 12982s
# [2025-07-09 20:53:13] Request 5457/27722: Fairfield → Tulelake (attempt 1)
# [2025-07-09 20:53:14]   ✅ Success: 509,088 meters, 17580s
# [2025-07-09 20:53:14] Request 5458/27722: Fairfield → Turlock (attempt 1)
# [2025-07-09 20:53:14]   ✅ Success: 157,437 meters, 6402s
# [2025-07-09 20:53:15] Request 5459/27722: Fairfield → Twentynine Palms (attempt 1)
# [2025-07-09 20:53:15]   ✅ Success: 831,465 meters, 29016s
# [2025-07-09 20:53:16] Request 5460/27722: Fairfield → Ukiah (attempt 1)
# [2025-07-09 20:53:16]   ✅ Success: 184,660 meters, 6915s
# [2025-07-09 20:53:16] Progress saved: 5460 completed, 0 failed, 22262 remaining
# [2025-07-09 20:53:17] Request 5461/27722: Fairfield → Vacaville (attempt 1)
# [2025-07-09 20:53:17]   ✅ Success: 18,946 meters, 730s
# [2025-07-09 20:53:17] Request 5462/27722: Fairfield → Vallejo (attempt 1)
# [2025-07-09 20:53:18]   ✅ Success: 23,133 meters, 1149s
# [2025-07-09 20:53:18] Request 5463/27722: Fairfield → Van Nuys (attempt 1)
# [2025-07-09 20:53:19]   ✅ Success: 608,137 meters, 20372s
# [2025-07-09 20:53:19] Request 5464/27722: Fairfield → Ventura (attempt 1)
# [2025-07-09 20:53:19]   ✅ Success: 615,192 meters, 21245s
# [2025-07-09 20:53:20] Request 5465/27722: Fairfield → Victorville (attempt 1)
# [2025-07-09 20:53:20]   ✅ Success: 688,357 meters, 23905s
# [2025-07-09 20:53:21] Request 5466/27722: Fairfield → Visalia (attempt 1)
# [2025-07-09 20:53:21]   ✅ Success: 357,821 meters, 12923s
# [2025-07-09 20:53:21] Request 5467/27722: Fairfield → Watsonville (attempt 1)
# [2025-07-09 20:53:22]   ✅ Success: 191,348 meters, 7342s
# [2025-07-09 20:53:22] Request 5468/27722: Fairfield → Weaverville (attempt 1)
# [2025-07-09 20:53:22]   ✅ Success: 345,458 meters, 12013s
# [2025-07-09 20:53:23] Request 5469/27722: Fairfield → West Covina (attempt 1)
# [2025-07-09 20:53:23]   ✅ Success: 659,902 meters, 22523s
# [2025-07-09 20:53:24] Request 5470/27722: Fairfield → West Hollywood (attempt 1)
# [2025-07-09 20:53:24]   ✅ Success: 622,356 meters, 21225s
# [2025-07-09 20:53:24] Progress saved: 5470 completed, 0 failed, 22252 remaining
# [2025-07-09 20:53:25] Request 5471/27722: Fairfield → West Sacramento Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:53:25]   ✅ Success: 63,600 meters, 2286s
# [2025-07-09 20:53:25] Request 5472/27722: Fairfield → Westminster (attempt 1)
# [2025-07-09 20:53:26]   ✅ Success: 684,358 meters, 23139s
# [2025-07-09 20:53:26] Request 5473/27722: Fairfield → Whittier (attempt 1)
# [2025-07-09 20:53:27]   ✅ Success: 654,311 meters, 22844s
# [2025-07-09 20:53:27] Request 5474/27722: Fairfield → Willows (attempt 1)
# [2025-07-09 20:53:27]   ✅ Success: 154,412 meters, 5115s
# [2025-07-09 20:53:28] Request 5475/27722: Fairfield → Winnetka (attempt 1)
# [2025-07-09 20:53:28]   ✅ Success: 616,574 meters, 21033s
# [2025-07-09 20:53:28] Request 5476/27722: Fairfield → Woodland (attempt 1)
# [2025-07-09 20:53:29]   ✅ Success: 58,889 meters, 2143s
# [2025-07-09 20:53:29] Request 5477/27722: Fairfield → Yreka (attempt 1)
# [2025-07-09 20:53:30]   ✅ Success: 427,625 meters, 14346s
# [2025-07-09 20:53:30] Request 5478/27722: Fairfield → Yuba City (attempt 1)
# [2025-07-09 20:53:30]   ✅ Success: 118,933 meters, 4672s
# [2025-07-09 20:53:31] Request 5479/27722: Fall River Mills → Alturas (attempt 1)
# [2025-07-09 20:53:31]   ✅ Success: 116,852 meters, 4484s
# [2025-07-09 20:53:31] Request 5480/27722: Fall River Mills → Arleta (attempt 1)
# [2025-07-09 20:53:32]   ✅ Success: 955,987 meters, 32596s
# [2025-07-09 20:53:32] Progress saved: 5480 completed, 0 failed, 22242 remaining
# [2025-07-09 20:53:32] Request 5481/27722: Fall River Mills → Arvin (attempt 1)
# [2025-07-09 20:53:33]   ✅ Success: 850,350 meters, 29257s
# [2025-07-09 20:53:33] Request 5482/27722: Fall River Mills → Auburn (attempt 1)
# [2025-07-09 20:53:34]   ✅ Success: 362,079 meters, 14740s
# [2025-07-09 20:53:34] Request 5483/27722: Fall River Mills → Bakersfield (attempt 1)
# [2025-07-09 20:53:34]   ✅ Success: 812,951 meters, 28015s
# [2025-07-09 20:53:35] Request 5484/27722: Fall River Mills → Bakersfield Southwest (attempt 1)
# [2025-07-09 20:53:35]   ✅ Success: 826,344 meters, 28411s
# [2025-07-09 20:53:36] Request 5485/27722: Fall River Mills → Barstow (attempt 1)
# [2025-07-09 20:53:36]   ✅ Success: 942,204 meters, 34609s
# [2025-07-09 20:53:36] Request 5486/27722: Fall River Mills → Bell Gardens (attempt 1)
# [2025-07-09 20:53:37]   ✅ Success: 1,001,720 meters, 34651s
# [2025-07-09 20:53:37] Request 5487/27722: Fall River Mills → Bellflower (attempt 1)
# [2025-07-09 20:53:38]   ✅ Success: 1,017,807 meters, 35067s
# [2025-07-09 20:53:38] Request 5488/27722: Fall River Mills → Bishop (attempt 1)
# [2025-07-09 20:53:39]   ✅ Success: 599,720 meters, 22523s
# [2025-07-09 20:53:39] Request 5489/27722: Fall River Mills → Blythe (attempt 1)
# [2025-07-09 20:53:39]   ✅ Success: 1,342,930 meters, 45501s
# [2025-07-09 20:53:40] Request 5490/27722: Fall River Mills → Brawley (attempt 1)
# [2025-07-09 20:53:40]   ✅ Success: 1,305,151 meters, 44515s
# [2025-07-09 20:53:40] Progress saved: 5490 completed, 0 failed, 22232 remaining
# [2025-07-09 20:53:41] Request 5491/27722: Fall River Mills → Carmichael (attempt 1)
# [2025-07-09 20:53:41]   ✅ Success: 382,050 meters, 13897s
# [2025-07-09 20:53:42] Request 5492/27722: Fall River Mills → Chico (attempt 1)
# [2025-07-09 20:53:42]   ✅ Success: 223,001 meters, 8852s
# [2025-07-09 20:53:42] Request 5493/27722: Fall River Mills → Chula Vista (attempt 1)
# [2025-07-09 20:53:43]   ✅ Success: 1,199,251 meters, 40861s
# [2025-07-09 20:53:43] Request 5494/27722: Fall River Mills → Clovis (attempt 1)
# [2025-07-09 20:53:44]   ✅ Success: 658,647 meters, 23261s
# [2025-07-09 20:53:44] Request 5495/27722: Fall River Mills → Coalinga (attempt 1)
# [2025-07-09 20:53:45]   ✅ Success: 681,793 meters, 23515s
# [2025-07-09 20:53:45] Request 5496/27722: Fall River Mills → Colusa (attempt 1)
# [2025-07-09 20:53:46]   ✅ Success: 284,209 meters, 10646s
# [2025-07-09 20:53:46] Request 5497/27722: Fall River Mills → Compton (attempt 1)
# [2025-07-09 20:53:46]   ✅ Success: 1,015,967 meters, 34713s
# [2025-07-09 20:53:47] Request 5498/27722: Fall River Mills → Concord (attempt 1)
# [2025-07-09 20:53:47]   ✅ Success: 425,653 meters, 15015s
# [2025-07-09 20:53:48] Request 5499/27722: Fall River Mills → Corte Madera (attempt 1)
# [2025-07-09 20:53:48]   ✅ Success: 456,077 meters, 16183s
# [2025-07-09 20:53:48] Request 5500/27722: Fall River Mills → Costa Mesa (attempt 1)
# [2025-07-09 20:53:49]   ✅ Success: 1,057,031 meters, 36185s
# [2025-07-09 20:53:49] Progress saved: 5500 completed, 0 failed, 22222 remaining
# [2025-07-09 20:53:49] Request 5501/27722: Fall River Mills → Crescent City (attempt 1)
# [2025-07-09 20:53:50]   ✅ Success: 413,235 meters, 16466s
# [2025-07-09 20:53:50] Request 5502/27722: Fall River Mills → Culver City (attempt 1)
# [2025-07-09 20:53:50]   ✅ Success: 984,431 meters, 33579s
# [2025-07-09 20:53:51] Request 5503/27722: Fall River Mills → Daly City (attempt 1)
# [2025-07-09 20:53:51]   ✅ Success: 470,052 meters, 16745s
# [2025-07-09 20:53:52] Request 5504/27722: Fall River Mills → Davis (attempt 1)
# [2025-07-09 20:53:52]   ✅ Success: 358,096 meters, 12932s
# [2025-07-09 20:53:52] Request 5505/27722: Fall River Mills → Delano (attempt 1)
# [2025-07-09 20:53:53]   ✅ Success: 765,227 meters, 26544s
# [2025-07-09 20:53:53] Request 5506/27722: Fall River Mills → El Cajon (attempt 1)
# [2025-07-09 20:53:54]   ✅ Success: 1,197,077 meters, 40697s
# [2025-07-09 20:53:54] Request 5507/27722: Fall River Mills → El Centro (attempt 1)
# [2025-07-09 20:53:55]   ✅ Success: 1,324,321 meters, 45272s
# [2025-07-09 20:53:55] Request 5508/27722: Fall River Mills → El Cerrito (attempt 1)
# [2025-07-09 20:53:55]   ✅ Success: 434,237 meters, 15408s
# [2025-07-09 20:53:56] Request 5509/27722: Fall River Mills → El Monte (attempt 1)
# [2025-07-09 20:53:56]   ✅ Success: 1,004,411 meters, 34562s
# [2025-07-09 20:53:57] Request 5510/27722: Fall River Mills → Eureka (attempt 1)
# [2025-07-09 20:53:57]   ✅ Success: 352,286 meters, 15870s
# [2025-07-09 20:53:57] Progress saved: 5510 completed, 0 failed, 22212 remaining
# [2025-07-09 20:53:57] Request 5511/27722: Fall River Mills → Fairfield (attempt 1)
# [2025-07-09 20:53:58]   ✅ Success: 388,790 meters, 13709s
# [2025-07-09 20:53:58] Request 5512/27722: Fall River Mills → Folsom (attempt 1)
# [2025-07-09 20:53:58]   ✅ Success: 405,824 meters, 14554s
# [2025-07-09 20:53:59] Request 5513/27722: Fall River Mills → Fontana (attempt 1)
# [2025-07-09 20:53:59]   ✅ Success: 1,053,293 meters, 36034s
# [2025-07-09 20:54:00] Request 5514/27722: Fall River Mills → Fontana Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:54:00]   ✅ Success: 1,059,360 meters, 36182s
# [2025-07-09 20:54:01] Request 5515/27722: Fall River Mills → Fort Bragg (attempt 1)
# [2025-07-09 20:54:01]   ✅ Success: 481,460 meters, 19530s
# [2025-07-09 20:54:01] Request 5516/27722: Fall River Mills → Fremont (attempt 1)
# [2025-07-09 20:54:02]   ✅ Success: 488,716 meters, 17471s
# [2025-07-09 20:54:02] Request 5517/27722: Fall River Mills → Fresno (attempt 1)
# [2025-07-09 20:54:03]   ✅ Success: 637,446 meters, 22305s
# [2025-07-09 20:54:03] Request 5518/27722: Fall River Mills → Fresno Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:54:03]   ✅ Success: 646,305 meters, 22527s
# [2025-07-09 20:54:04] Request 5519/27722: Fall River Mills → Fresno North (attempt 1)
# [2025-07-09 20:54:04]   ✅ Success: 637,166 meters, 22740s
# [2025-07-09 20:54:05] Request 5520/27722: Fall River Mills → Fullerton (attempt 1)
# [2025-07-09 20:54:05]   ✅ Success: 1,025,391 meters, 35536s
# [2025-07-09 20:54:05] Progress saved: 5520 completed, 0 failed, 22202 remaining
# [2025-07-09 20:54:06] Request 5521/27722: Fall River Mills → Garberville (attempt 1)
# [2025-07-09 20:54:06]   ✅ Success: 425,981 meters, 18733s
# [2025-07-09 20:54:07] Request 5522/27722: Fall River Mills → Gardena Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:54:07]   ✅ Success: 1,007,630 meters, 34586s
# [2025-07-09 20:54:07] Request 5523/27722: Fall River Mills → Gilroy (attempt 1)
# [2025-07-09 20:54:08]   ✅ Success: 553,447 meters, 19276s
# [2025-07-09 20:54:08] Request 5524/27722: Fall River Mills → Glendale (attempt 1)
# [2025-07-09 20:54:09]   ✅ Success: 973,617 meters, 33179s
# [2025-07-09 20:54:09] Request 5525/27722: Fall River Mills → Goleta (attempt 1)
# [2025-07-09 20:54:09]   ✅ Success: 951,584 meters, 32469s
# [2025-07-09 20:54:10] Request 5526/27722: Fall River Mills → Grass Valley (attempt 1)
# [2025-07-09 20:54:10]   ✅ Success: 346,461 meters, 13455s
# [2025-07-09 20:54:11] Request 5527/27722: Fall River Mills → Hanford (attempt 1)
# [2025-07-09 20:54:11]   ✅ Success: 692,181 meters, 24581s
# [2025-07-09 20:54:12] Request 5528/27722: Fall River Mills → Hawthorne (attempt 1)
# [2025-07-09 20:54:12]   ✅ Success: 998,559 meters, 34316s
# [2025-07-09 20:54:13] Request 5529/27722: Fall River Mills → Hayward (attempt 1)
# [2025-07-09 20:54:13]   ✅ Success: 475,769 meters, 16896s
# [2025-07-09 20:54:13] Request 5530/27722: Fall River Mills → Hemet (attempt 1)
# [2025-07-09 20:54:14]   ✅ Success: 1,121,290 meters, 39002s
# [2025-07-09 20:54:14] Progress saved: 5530 completed, 0 failed, 22192 remaining
# [2025-07-09 20:54:14] Request 5531/27722: Fall River Mills → Hollister (attempt 1)
# [2025-07-09 20:54:15]   ✅ Success: 576,630 meters, 20246s
# [2025-07-09 20:54:15] Request 5532/27722: Fall River Mills → Hollywood (attempt 1)
# [2025-07-09 20:54:16]   ✅ Success: 977,021 meters, 33500s
# [2025-07-09 20:54:16] Request 5533/27722: Fall River Mills → Indio (attempt 1)
# [2025-07-09 20:54:17]   ✅ Success: 1,189,106 meters, 40264s
# [2025-07-09 20:54:17] Request 5534/27722: Fall River Mills → Jackson (attempt 1)
# [2025-07-09 20:54:17]   ✅ Success: 448,043 meters, 16733s
# [2025-07-09 20:54:18] Request 5535/27722: Fall River Mills → King City (attempt 1)
# [2025-07-09 20:54:18]   ✅ Success: 673,845 meters, 23388s
# [2025-07-09 20:54:19] Request 5536/27722: Fall River Mills → Lake Isabella (attempt 1)
# [2025-07-09 20:54:19]   ✅ Success: 822,059 meters, 30571s
# [2025-07-09 20:54:19] Request 5537/27722: Fall River Mills → Lakeport (attempt 1)
# [2025-07-09 20:54:20]   ✅ Success: 379,906 meters, 14330s
# [2025-07-09 20:54:20] Request 5538/27722: Fall River Mills → Lancaster (attempt 1)
# [2025-07-09 20:54:21]   ✅ Success: 949,801 meters, 32440s
# [2025-07-09 20:54:21] Request 5539/27722: Fall River Mills → Lincoln Park (attempt 1)
# [2025-07-09 20:54:21]   ✅ Success: 986,995 meters, 33934s
# [2025-07-09 20:54:22] Request 5540/27722: Fall River Mills → Lodi (attempt 1)
# [2025-07-09 20:54:22]   ✅ Success: 428,616 meters, 15267s
# [2025-07-09 20:54:22] Progress saved: 5540 completed, 0 failed, 22182 remaining
# [2025-07-09 20:54:23] Request 5541/27722: Fall River Mills → Lompoc (attempt 1)
# [2025-07-09 20:54:23]   ✅ Success: 893,017 meters, 30717s
# [2025-07-09 20:54:24] Request 5542/27722: Fall River Mills → Long Beach (attempt 1)
# [2025-07-09 20:54:24]   ✅ Success: 1,022,233 meters, 34995s
# [2025-07-09 20:54:25] Request 5543/27722: Fall River Mills → Los Angeles (attempt 1)
# [2025-07-09 20:54:25]   ✅ Success: 992,598 meters, 34098s
# [2025-07-09 20:54:25] Request 5544/27722: Fall River Mills → Los Banos (attempt 1)
# [2025-07-09 20:54:26]   ✅ Success: 566,050 meters, 19811s
# [2025-07-09 20:54:26] Request 5545/27722: Fall River Mills → Los Gatos (attempt 1)
# [2025-07-09 20:54:27]   ✅ Success: 520,221 meters, 18404s
# [2025-07-09 20:54:27] Request 5546/27722: Fall River Mills → Madera (attempt 1)
# [2025-07-09 20:54:27]   ✅ Success: 607,036 meters, 21327s
# [2025-07-09 20:54:28] Request 5547/27722: Fall River Mills → Manteca (attempt 1)
# [2025-07-09 20:54:28]   ✅ Success: 464,644 meters, 16711s
# [2025-07-09 20:54:29] Request 5548/27722: Fall River Mills → Mariposa (attempt 1)
# [2025-07-09 20:54:29]   ✅ Success: 612,848 meters, 22118s
# [2025-07-09 20:54:30] Request 5549/27722: Fall River Mills → Mendota (attempt 1)
# [2025-07-09 20:54:30]   ✅ Success: 628,465 meters, 22039s
# [2025-07-09 20:54:30] Request 5550/27722: Fall River Mills → Merced (attempt 1)
# [2025-07-09 20:54:31]   ✅ Success: 550,606 meters, 19367s
# [2025-07-09 20:54:31] Progress saved: 5550 completed, 0 failed, 22172 remaining
# [2025-07-09 20:54:31] Request 5551/27722: Fall River Mills → Modesto (attempt 1)
# [2025-07-09 20:54:31]   ✅ Success: 491,504 meters, 17546s
# [2025-07-09 20:54:32] Request 5552/27722: Fall River Mills → Montebello (attempt 1)
# [2025-07-09 20:54:32]   ✅ Success: 1,000,416 meters, 34486s
# [2025-07-09 20:54:33] Request 5553/27722: Fall River Mills → Mt Shasta (attempt 1)
# [2025-07-09 20:54:33]   ✅ Success: 97,194 meters, 3901s
# [2025-07-09 20:54:34] Request 5554/27722: Fall River Mills → Napa (attempt 1)
# [2025-07-09 20:54:34]   ✅ Success: 407,898 meters, 14402s
# [2025-07-09 20:54:34] Request 5555/27722: Fall River Mills → Needles (attempt 1)
# [2025-07-09 20:54:34]   ✅ Success: 1,162,510 meters, 40756s
# [2025-07-09 20:54:35] Request 5556/27722: Fall River Mills → Newhall (attempt 1)
# [2025-07-09 20:54:35]   ✅ Success: 938,789 meters, 32084s
# [2025-07-09 20:54:36] Request 5557/27722: Fall River Mills → Norco (attempt 1)
# [2025-07-09 20:54:36]   ✅ Success: 1,060,765 meters, 36337s
# [2025-07-09 20:54:37] Request 5558/27722: Fall River Mills → Novato (attempt 1)
# [2025-07-09 20:54:37]   ✅ Success: 442,966 meters, 15814s
# [2025-07-09 20:54:37] Request 5559/27722: Fall River Mills → Oakland (attempt 1)
# [2025-07-09 20:54:38]   ✅ Success: 448,486 meters, 15810s
# [2025-07-09 20:54:38] Request 5560/27722: Fall River Mills → Oceanside (attempt 1)
# [2025-07-09 20:54:39]   ✅ Success: 1,138,298 meters, 38694s
# [2025-07-09 20:54:39] Progress saved: 5560 completed, 0 failed, 22162 remaining
# [2025-07-09 20:54:39] Request 5561/27722: Fall River Mills → Oroville (attempt 1)
# [2025-07-09 20:54:40]   ✅ Success: 260,202 meters, 10124s
# [2025-07-09 20:54:40] Request 5562/27722: Fall River Mills → Oxnard (attempt 1)
# [2025-07-09 20:54:40]   ✅ Success: 1,002,588 meters, 35152s
# [2025-07-09 20:54:41] Request 5563/27722: Fall River Mills → Palm Desert (attempt 1)
# [2025-07-09 20:54:41]   ✅ Success: 1,174,497 meters, 39872s
# [2025-07-09 20:54:42] Request 5564/27722: Fall River Mills → Palm Springs (attempt 1)
# [2025-07-09 20:54:42]   ✅ Success: 1,158,121 meters, 39484s
# [2025-07-09 20:54:43] Request 5565/27722: Fall River Mills → Pasadena (attempt 1)
# [2025-07-09 20:54:43]   ✅ Success: 994,424 meters, 33893s
# [2025-07-09 20:54:44] Request 5566/27722: Fall River Mills → Paso Robles (attempt 1)
# [2025-07-09 20:54:44]   ✅ Success: 756,307 meters, 25926s
# [2025-07-09 20:54:45] Request 5567/27722: Fall River Mills → Petaluma (attempt 1)
# [2025-07-09 20:54:45]   ✅ Success: 450,758 meters, 16352s
# [2025-07-09 20:54:45] Request 5568/27722: Fall River Mills → Pittsburg (attempt 1)
# [2025-07-09 20:54:46]   ✅ Success: 441,486 meters, 15664s
# [2025-07-09 20:54:46] Request 5569/27722: Fall River Mills → Placerville (attempt 1)
# [2025-07-09 20:54:46]   ✅ Success: 438,908 meters, 15578s
# [2025-07-09 20:54:47] Request 5570/27722: Fall River Mills → Pleasanton (attempt 1)
# [2025-07-09 20:54:47]   ✅ Success: 462,412 meters, 16294s
# [2025-07-09 20:54:47] Progress saved: 5570 completed, 0 failed, 22152 remaining
# [2025-07-09 20:54:48] Request 5571/27722: Fall River Mills → Pomona (attempt 1)
# [2025-07-09 20:54:48]   ✅ Success: 1,031,279 meters, 35509s
# [2025-07-09 20:54:49] Request 5572/27722: Fall River Mills → Porterville (attempt 1)
# [2025-07-09 20:54:49]   ✅ Success: 752,190 meters, 26727s
# [2025-07-09 20:54:50] Request 5573/27722: Fall River Mills → Poway (attempt 1)
# [2025-07-09 20:54:50]   ✅ Success: 1,181,286 meters, 40476s
# [2025-07-09 20:54:51] Request 5574/27722: Fall River Mills → Quincy (attempt 1)
# [2025-07-09 20:54:51]   ✅ Success: 206,850 meters, 8779s
# [2025-07-09 20:54:51] Request 5575/27722: Fall River Mills → Rancho Cucamonga (attempt 1)
# [2025-07-09 20:54:52]   ✅ Success: 1,042,733 meters, 35793s
# [2025-07-09 20:54:52] Request 5576/27722: Fall River Mills → Rancho San Diego Industry Business Center (attempt 1)
# [2025-07-09 20:54:53]   ✅ Success: 1,205,195 meters, 41183s
# [2025-07-09 20:54:53] Request 5577/27722: Fall River Mills → Red Bluff (attempt 1)
# [2025-07-09 20:54:53]   ✅ Success: 160,989 meters, 6391s
# [2025-07-09 20:54:54] Request 5578/27722: Fall River Mills → Redding (attempt 1)
# [2025-07-09 20:54:54]   ✅ Success: 115,506 meters, 4927s
# [2025-07-09 20:54:55] Request 5579/27722: Fall River Mills → Redlands (attempt 1)
# [2025-07-09 20:54:55]   ✅ Success: 1,081,379 meters, 36871s
# [2025-07-09 20:54:56] Request 5580/27722: Fall River Mills → Redwood City (attempt 1)
# [2025-07-09 20:54:56]   ✅ Success: 495,915 meters, 17739s
# [2025-07-09 20:54:56] Progress saved: 5580 completed, 0 failed, 22142 remaining
# [2025-07-09 20:54:57] Request 5581/27722: Fall River Mills → Reedley (attempt 1)
# [2025-07-09 20:54:57]   ✅ Success: 679,825 meters, 24123s
# [2025-07-09 20:54:57] Request 5582/27722: Fall River Mills → Ridgecrest (attempt 1)
# [2025-07-09 20:54:58]   ✅ Success: 817,394 meters, 30317s
# [2025-07-09 20:54:58] Request 5583/27722: Fall River Mills → Riverside (attempt 1)
# [2025-07-09 20:54:59]   ✅ Success: 1,074,914 meters, 36864s
# [2025-07-09 20:54:59] Request 5584/27722: Fall River Mills → Riverside East (attempt 1)
# [2025-07-09 20:55:00]   ✅ Success: 1,077,870 meters, 36897s
# [2025-07-09 20:55:00] Request 5585/27722: Fall River Mills → Rocklin (attempt 1)
# [2025-07-09 20:55:00]   ✅ Success: 361,486 meters, 14077s
# [2025-07-09 20:55:01] Request 5586/27722: Fall River Mills → Roseville (attempt 1)
# [2025-07-09 20:55:01]   ✅ Success: 355,280 meters, 13877s
# [2025-07-09 20:55:02] Request 5587/27722: Fall River Mills → Sacramento (attempt 1)
# [2025-07-09 20:55:02]   ✅ Success: 376,816 meters, 13606s
# [2025-07-09 20:55:02] Request 5588/27722: Fall River Mills → Sacramento South (attempt 1)
# [2025-07-09 20:55:02]   ✅ Success: 384,611 meters, 13684s
# [2025-07-09 20:55:03] Request 5589/27722: Fall River Mills → Salinas (attempt 1)
# [2025-07-09 20:55:03]   ✅ Success: 596,240 meters, 20778s
# [2025-07-09 20:55:04] Request 5590/27722: Fall River Mills → San Andreas (attempt 1)
# [2025-07-09 20:55:04]   ✅ Success: 478,596 meters, 17464s
# [2025-07-09 20:55:04] Progress saved: 5590 completed, 0 failed, 22132 remaining
# [2025-07-09 20:55:05] Request 5591/27722: Fall River Mills → San Bernardino (attempt 1)
# [2025-07-09 20:55:05]   ✅ Success: 1,071,219 meters, 36502s
# [2025-07-09 20:55:06] Request 5592/27722: Fall River Mills → San Clemente (attempt 1)
# [2025-07-09 20:55:06]   ✅ Success: 1,091,685 meters, 37280s
# [2025-07-09 20:55:06] Request 5593/27722: Fall River Mills → San Diego (attempt 1)
# [2025-07-09 20:55:07]   ✅ Success: 1,185,844 meters, 40247s
# [2025-07-09 20:55:07] Request 5594/27722: Fall River Mills → San Diego Clairemont (attempt 1)
# [2025-07-09 20:55:08]   ✅ Success: 1,176,979 meters, 40074s
# [2025-07-09 20:55:08] Request 5595/27722: Fall River Mills → San Francisco (attempt 1)
# [2025-07-09 20:55:08]   ✅ Success: 459,970 meters, 16691s
# [2025-07-09 20:55:09] Request 5596/27722: Fall River Mills → San Jose (attempt 1)
# [2025-07-09 20:55:09]   ✅ Success: 512,992 meters, 18066s
# [2025-07-09 20:55:10] Request 5597/27722: Fall River Mills → San Luis Obispo (attempt 1)
# [2025-07-09 20:55:10]   ✅ Success: 803,757 meters, 27514s
# [2025-07-09 20:55:11] Request 5598/27722: Fall River Mills → San Marcos (attempt 1)
# [2025-07-09 20:55:11]   ✅ Success: 1,156,430 meters, 39419s
# [2025-07-09 20:55:11] Request 5599/27722: Fall River Mills → San Mateo (attempt 1)
# [2025-07-09 20:55:12]   ✅ Success: 482,837 meters, 17150s
# [2025-07-09 20:55:12] Request 5600/27722: Fall River Mills → San Pedro (attempt 1)
# [2025-07-09 20:55:12]   ✅ Success: 1,019,396 meters, 34780s
# [2025-07-09 20:55:12] Progress saved: 5600 completed, 0 failed, 22122 remaining
# [2025-07-09 20:55:13] Request 5601/27722: Fall River Mills → San Ysidro (attempt 1)
# [2025-07-09 20:55:13]   ✅ Success: 1,212,245 meters, 41201s
# [2025-07-09 20:55:14] Request 5602/27722: Fall River Mills → Santa Ana (attempt 1)
# [2025-07-09 20:55:14]   ✅ Success: 1,037,056 meters, 36008s
# [2025-07-09 20:55:15] Request 5603/27722: Fall River Mills → Santa Barbara (attempt 1)
# [2025-07-09 20:55:15]   ✅ Success: 949,858 meters, 32843s
# [2025-07-09 20:55:16] Request 5604/27722: Fall River Mills → Santa Clara (attempt 1)
# [2025-07-09 20:55:16]   ✅ Success: 509,489 meters, 18367s
# [2025-07-09 20:55:17] Request 5605/27722: Fall River Mills → Santa Monica (attempt 1)
# [2025-07-09 20:55:17]   ✅ Success: 983,971 meters, 33610s
# [2025-07-09 20:55:17] Request 5606/27722: Fall River Mills → Santa Paula (attempt 1)
# [2025-07-09 20:55:18]   ✅ Success: 974,016 meters, 33356s
# [2025-07-09 20:55:18] Request 5607/27722: Fall River Mills → Santa Rosa (attempt 1)
# [2025-07-09 20:55:18]   ✅ Success: 473,919 meters, 16957s
# [2025-07-09 20:55:19] Request 5608/27722: Fall River Mills → Santa Teresa (attempt 1)
# [2025-07-09 20:55:19]   ✅ Success: 521,625 meters, 18363s
# [2025-07-09 20:55:20] Request 5609/27722: Fall River Mills → Seaside (attempt 1)
# [2025-07-09 20:55:20]   ✅ Success: 613,634 meters, 21397s
# [2025-07-09 20:55:21] Request 5610/27722: Fall River Mills → Shafter (attempt 1)
# [2025-07-09 20:55:21]   ✅ Success: 798,116 meters, 27450s
# [2025-07-09 20:55:21] Progress saved: 5610 completed, 0 failed, 22112 remaining
# [2025-07-09 20:55:21] Request 5611/27722: Fall River Mills → Simi Valley (attempt 1)
# [2025-07-09 20:55:22]   ✅ Success: 977,419 meters, 33264s
# [2025-07-09 20:55:22] Request 5612/27722: Fall River Mills → Sonora (attempt 1)
# [2025-07-09 20:55:22]   ✅ Success: 524,085 meters, 19912s
# [2025-07-09 20:55:23] Request 5613/27722: Fall River Mills → South Lake Tahoe (attempt 1)
# [2025-07-09 20:55:23]   ✅ Success: 369,973 meters, 14130s
# [2025-07-09 20:55:24] Request 5614/27722: Fall River Mills → Stockton (attempt 1)
# [2025-07-09 20:55:24]   ✅ Success: 446,506 meters, 15876s
# [2025-07-09 20:55:25] Request 5615/27722: Fall River Mills → Susanville (attempt 1)
# [2025-07-09 20:55:25]   ✅ Success: 139,919 meters, 5594s
# [2025-07-09 20:55:25] Request 5616/27722: Fall River Mills → Taft (attempt 1)
# [2025-07-09 20:55:26]   ✅ Success: 819,931 meters, 28319s
# [2025-07-09 20:55:26] Request 5617/27722: Fall River Mills → Temecula (attempt 1)
# [2025-07-09 20:55:27]   ✅ Success: 1,119,000 meters, 38165s
# [2025-07-09 20:55:27] Request 5618/27722: Fall River Mills → Thousand Oaks (attempt 1)
# [2025-07-09 20:55:27]   ✅ Success: 1,000,598 meters, 33998s
# [2025-07-09 20:55:28] Request 5619/27722: Fall River Mills → Torrance (attempt 1)
# [2025-07-09 20:55:28]   ✅ Success: 1,008,364 meters, 34608s
# [2025-07-09 20:55:29] Request 5620/27722: Fall River Mills → Tracy (attempt 1)
# [2025-07-09 20:55:29]   ✅ Success: 479,267 meters, 16865s
# [2025-07-09 20:55:29] Progress saved: 5620 completed, 0 failed, 22102 remaining
# [2025-07-09 20:55:30] Request 5621/27722: Fall River Mills → Truckee (attempt 1)
# [2025-07-09 20:55:30]   ✅ Success: 327,190 meters, 12288s
# [2025-07-09 20:55:30] Request 5622/27722: Fall River Mills → Tulare (attempt 1)
# [2025-07-09 20:55:31]   ✅ Success: 712,577 meters, 24818s
# [2025-07-09 20:55:31] Request 5623/27722: Fall River Mills → Tulelake (attempt 1)
# [2025-07-09 20:55:32]   ✅ Success: 140,506 meters, 5232s
# [2025-07-09 20:55:32] Request 5624/27722: Fall River Mills → Turlock (attempt 1)
# [2025-07-09 20:55:32]   ✅ Success: 510,998 meters, 18239s
# [2025-07-09 20:55:33] Request 5625/27722: Fall River Mills → Twentynine Palms (attempt 1)
# [2025-07-09 20:55:33]   ✅ Success: 1,094,202 meters, 40696s
# [2025-07-09 20:55:34] Request 5626/27722: Fall River Mills → Ukiah (attempt 1)
# [2025-07-09 20:55:34]   ✅ Success: 413,422 meters, 15816s
# [2025-07-09 20:55:34] Request 5627/27722: Fall River Mills → Vacaville (attempt 1)
# [2025-07-09 20:55:35]   ✅ Success: 368,765 meters, 13055s
# [2025-07-09 20:55:35] Request 5628/27722: Fall River Mills → Vallejo (attempt 1)
# [2025-07-09 20:55:35]   ✅ Success: 408,581 meters, 14505s
# [2025-07-09 20:55:36] Request 5629/27722: Fall River Mills → Van Nuys (attempt 1)
# [2025-07-09 20:55:36]   ✅ Success: 962,988 meters, 32834s
# [2025-07-09 20:55:37] Request 5630/27722: Fall River Mills → Ventura (attempt 1)
# [2025-07-09 20:55:37]   ✅ Success: 994,161 meters, 34116s
# [2025-07-09 20:55:37] Progress saved: 5630 completed, 0 failed, 22092 remaining
# [2025-07-09 20:55:38] Request 5631/27722: Fall River Mills → Victorville (attempt 1)
# [2025-07-09 20:55:38]   ✅ Success: 950,626 meters, 35500s
# [2025-07-09 20:55:39] Request 5632/27722: Fall River Mills → Visalia (attempt 1)
# [2025-07-09 20:55:39]   ✅ Success: 711,382 meters, 24760s
# [2025-07-09 20:55:39] Request 5633/27722: Fall River Mills → Watsonville (attempt 1)
# [2025-07-09 20:55:40]   ✅ Success: 576,796 meters, 20699s
# [2025-07-09 20:55:40] Request 5634/27722: Fall River Mills → Weaverville (attempt 1)
# [2025-07-09 20:55:40]   ✅ Success: 180,515 meters, 7782s
# [2025-07-09 20:55:41] Request 5635/27722: Fall River Mills → West Covina (attempt 1)
# [2025-07-09 20:55:41]   ✅ Success: 1,014,753 meters, 34985s
# [2025-07-09 20:55:42] Request 5636/27722: Fall River Mills → West Hollywood (attempt 1)
# [2025-07-09 20:55:42]   ✅ Success: 977,206 meters, 33687s
# [2025-07-09 20:55:43] Request 5637/27722: Fall River Mills → West Sacramento Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:55:43]   ✅ Success: 372,528 meters, 13271s
# [2025-07-09 20:55:43] Request 5638/27722: Fall River Mills → Westminster (attempt 1)
# [2025-07-09 20:55:44]   ✅ Success: 1,039,208 meters, 35601s
# [2025-07-09 20:55:44] Request 5639/27722: Fall River Mills → Whittier (attempt 1)
# [2025-07-09 20:55:44]   ✅ Success: 1,009,161 meters, 35306s
# [2025-07-09 20:55:45] Request 5640/27722: Fall River Mills → Willows (attempt 1)
# [2025-07-09 20:55:45]   ✅ Success: 233,992 meters, 8736s
# [2025-07-09 20:55:45] Progress saved: 5640 completed, 0 failed, 22082 remaining
# [2025-07-09 20:55:46] Request 5641/27722: Fall River Mills → Winnetka (attempt 1)
# [2025-07-09 20:55:46]   ✅ Success: 971,424 meters, 33495s
# [2025-07-09 20:55:47] Request 5642/27722: Fall River Mills → Woodland (attempt 1)
# [2025-07-09 20:55:47]   ✅ Success: 341,657 meters, 12356s
# [2025-07-09 20:55:48] Request 5643/27722: Fall River Mills → Yreka (attempt 1)
# [2025-07-09 20:55:48]   ✅ Success: 153,318 meters, 5822s
# [2025-07-09 20:55:48] Request 5644/27722: Fall River Mills → Yuba City (attempt 1)
# [2025-07-09 20:55:48]   ✅ Success: 296,922 meters, 11772s
# [2025-07-09 20:55:49] Request 5645/27722: Folsom → Alturas (attempt 1)
# [2025-07-09 20:55:49]   ✅ Success: 466,960 meters, 17388s
# [2025-07-09 20:55:50] Request 5646/27722: Folsom → Arleta (attempt 1)
# [2025-07-09 20:55:50]   ✅ Success: 621,170 meters, 20949s
# [2025-07-09 20:55:50] Request 5647/27722: Folsom → Arvin (attempt 1)
# [2025-07-09 20:55:51]   ✅ Success: 506,977 meters, 17498s
# [2025-07-09 20:55:51] Request 5648/27722: Folsom → Auburn (attempt 1)
# [2025-07-09 20:55:52]   ✅ Success: 31,648 meters, 1957s
# [2025-07-09 20:55:52] Request 5649/27722: Folsom → Bakersfield (attempt 1)
# [2025-07-09 20:55:52]   ✅ Success: 471,231 meters, 16071s
# [2025-07-09 20:55:53] Request 5650/27722: Folsom → Bakersfield Southwest (attempt 1)
# [2025-07-09 20:55:53]   ✅ Success: 482,259 meters, 16633s
# [2025-07-09 20:55:53] Progress saved: 5650 completed, 0 failed, 22072 remaining
# [2025-07-09 20:55:54] Request 5651/27722: Folsom → Barstow (attempt 1)
# [2025-07-09 20:55:54]   ✅ Success: 682,249 meters, 23262s
# [2025-07-09 20:55:55] Request 5652/27722: Folsom → Bell Gardens (attempt 1)
# [2025-07-09 20:55:55]   ✅ Success: 666,903 meters, 23005s
# [2025-07-09 20:55:55] Request 5653/27722: Folsom → Bellflower (attempt 1)
# [2025-07-09 20:55:56]   ✅ Success: 682,990 meters, 23420s
# [2025-07-09 20:55:56] Request 5654/27722: Folsom → Bishop (attempt 1)
# [2025-07-09 20:55:57]   ✅ Success: 404,234 meters, 16431s
# [2025-07-09 20:55:57] Request 5655/27722: Folsom → Blythe (attempt 1)
# [2025-07-09 20:55:57]   ✅ Success: 1,008,112 meters, 33855s
# [2025-07-09 20:55:58] Request 5656/27722: Folsom → Brawley (attempt 1)
# [2025-07-09 20:55:58]   ✅ Success: 970,333 meters, 32869s
# [2025-07-09 20:55:59] Request 5657/27722: Folsom → Carmichael (attempt 1)
# [2025-07-09 20:55:59]   ✅ Success: 22,980 meters, 1536s
# [2025-07-09 20:56:00] Request 5658/27722: Folsom → Chico (attempt 1)
# [2025-07-09 20:56:00]   ✅ Success: 156,303 meters, 6507s
# [2025-07-09 20:56:01] Request 5659/27722: Folsom → Chula Vista (attempt 1)
# [2025-07-09 20:56:01]   ✅ Success: 864,434 meters, 29215s
# [2025-07-09 20:56:02] Request 5660/27722: Folsom → Clovis (attempt 1)
# [2025-07-09 20:56:02]   ✅ Success: 316,927 meters, 11317s
# [2025-07-09 20:56:02] Progress saved: 5660 completed, 0 failed, 22062 remaining
# [2025-07-09 20:56:02] Request 5661/27722: Folsom → Coalinga (attempt 1)
# [2025-07-09 20:56:03]   ✅ Success: 346,976 meters, 11869s
# [2025-07-09 20:56:03] Request 5662/27722: Folsom → Colusa (attempt 1)
# [2025-07-09 20:56:04]   ✅ Success: 141,014 meters, 5284s
# [2025-07-09 20:56:04] Request 5663/27722: Folsom → Compton (attempt 1)
# [2025-07-09 20:56:04]   ✅ Success: 681,149 meters, 23066s
# [2025-07-09 20:56:05] Request 5664/27722: Folsom → Concord (attempt 1)
# [2025-07-09 20:56:05]   ✅ Success: 140,741 meters, 5179s
# [2025-07-09 20:56:06] Request 5665/27722: Folsom → Corte Madera (attempt 1)
# [2025-07-09 20:56:06]   ✅ Success: 171,165 meters, 6347s
# [2025-07-09 20:56:07] Request 5666/27722: Folsom → Costa Mesa (attempt 1)
# [2025-07-09 20:56:07]   ✅ Success: 722,214 meters, 24538s
# [2025-07-09 20:56:07] Request 5667/27722: Folsom → Crescent City (attempt 1)
# [2025-07-09 20:56:08]   ✅ Success: 637,392 meters, 24895s
# [2025-07-09 20:56:08] Request 5668/27722: Folsom → Culver City (attempt 1)
# [2025-07-09 20:56:09]   ✅ Success: 649,613 meters, 21933s
# [2025-07-09 20:56:09] Request 5669/27722: Folsom → Daly City (attempt 1)
# [2025-07-09 20:56:09]   ✅ Success: 185,140 meters, 6909s
# [2025-07-09 20:56:10] Request 5670/27722: Folsom → Davis (attempt 1)
# [2025-07-09 20:56:10]   ✅ Success: 56,144 meters, 2419s
# [2025-07-09 20:56:10] Progress saved: 5670 completed, 0 failed, 22052 remaining
# [2025-07-09 20:56:11] Request 5671/27722: Folsom → Delano (attempt 1)
# [2025-07-09 20:56:11]   ✅ Success: 423,507 meters, 14600s
# [2025-07-09 20:56:12] Request 5672/27722: Folsom → El Cajon (attempt 1)
# [2025-07-09 20:56:12]   ✅ Success: 862,259 meters, 29051s
# [2025-07-09 20:56:12] Request 5673/27722: Folsom → El Centro (attempt 1)
# [2025-07-09 20:56:13]   ✅ Success: 989,503 meters, 33625s
# [2025-07-09 20:56:13] Request 5674/27722: Folsom → El Cerrito (attempt 1)
# [2025-07-09 20:56:14]   ✅ Success: 149,325 meters, 5572s
# [2025-07-09 20:56:14] Request 5675/27722: Folsom → El Monte (attempt 1)
# [2025-07-09 20:56:14]   ✅ Success: 669,594 meters, 22916s
# [2025-07-09 20:56:15] Request 5676/27722: Folsom → Eureka (attempt 1)
# [2025-07-09 20:56:15]   ✅ Success: 496,967 meters, 19091s
# [2025-07-09 20:56:16] Request 5677/27722: Folsom → Fairfield (attempt 1)
# [2025-07-09 20:56:16]   ✅ Success: 103,878 meters, 3872s
# [2025-07-09 20:56:16] Request 5678/27722: Folsom → Fall River Mills (attempt 1)
# [2025-07-09 20:56:17]   ✅ Success: 404,813 meters, 14411s
# [2025-07-09 20:56:17] Request 5679/27722: Folsom → Fontana (attempt 1)
# [2025-07-09 20:56:18]   ✅ Success: 718,476 meters, 24387s
# [2025-07-09 20:56:18] Request 5680/27722: Folsom → Fontana Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:56:19]   ✅ Success: 724,542 meters, 24536s
# [2025-07-09 20:56:19] Progress saved: 5680 completed, 0 failed, 22042 remaining
# [2025-07-09 20:56:19] Request 5681/27722: Folsom → Fort Bragg (attempt 1)
# [2025-07-09 20:56:19]   ✅ Success: 338,813 meters, 14236s
# [2025-07-09 20:56:20] Request 5682/27722: Folsom → Fremont (attempt 1)
# [2025-07-09 20:56:20]   ✅ Success: 203,804 meters, 7635s
# [2025-07-09 20:56:21] Request 5683/27722: Folsom → Fresno (attempt 1)
# [2025-07-09 20:56:21]   ✅ Success: 295,726 meters, 10361s
# [2025-07-09 20:56:21] Request 5684/27722: Folsom → Fresno Commercial Drive Test Center (attempt 1)
# [2025-07-09 20:56:22]   ✅ Success: 304,585 meters, 10583s
# [2025-07-09 20:56:22] Request 5685/27722: Folsom → Fresno North (attempt 1)
# [2025-07-09 20:56:23]   ✅ Success: 295,447 meters, 10796s
# [2025-07-09 20:56:23] Request 5686/27722: Folsom → Fullerton (attempt 1)
# [2025-07-09 20:56:23]   ✅ Success: 690,574 meters, 23889s
# [2025-07-09 20:56:24] Request 5687/27722: Folsom → Garberville (attempt 1)
# [2025-07-09 20:56:24]   ✅ Success: 395,334 meters, 15559s
# ...
# [2025-07-10 01:46:47]   ✅ Success: 694,456 meters, 24142s
# [2025-07-10 01:46:48] Request 27616/27722: Yuba City → Lakeport (attempt 1)
# [2025-07-10 01:46:48]   ✅ Success: 155,594 meters, 6588s
# [2025-07-10 01:46:48] Request 27617/27722: Yuba City → Lancaster (attempt 1)
# [2025-07-10 01:46:49]   ✅ Success: 647,781 meters, 21934s
# [2025-07-10 01:46:49] Request 27618/27722: Yuba City → Lincoln Park (attempt 1)
# [2025-07-10 01:46:49]   ✅ Success: 684,978 meters, 23444s
# [2025-07-10 01:46:50] Request 27619/27722: Yuba City → Lodi (attempt 1)
# [2025-07-10 01:46:50]   ✅ Success: 126,598 meters, 4778s
# [2025-07-10 01:46:51] Request 27620/27722: Yuba City → Lompoc (attempt 1)
# [2025-07-10 01:46:51]   ✅ Success: 631,331 meters, 21902s
# [2025-07-10 01:46:51] Progress saved: 27620 completed, 0 failed, 102 remaining
# [2025-07-10 01:46:52] Request 27621/27722: Yuba City → Long Beach (attempt 1)
# [2025-07-10 01:46:52]   ✅ Success: 720,215 meters, 24505s
# [2025-07-10 01:46:52] Request 27622/27722: Yuba City → Los Angeles (attempt 1)
# [2025-07-10 01:46:53]   ✅ Success: 690,581 meters, 23609s
# [2025-07-10 01:46:53] Request 27623/27722: Yuba City → Los Banos (attempt 1)
# [2025-07-10 01:46:53]   ✅ Success: 264,032 meters, 9322s
# [2025-07-10 01:46:54] Request 27624/27722: Yuba City → Los Gatos (attempt 1)
# [2025-07-10 01:46:54]   ✅ Success: 251,060 meters, 9561s
# [2025-07-10 01:46:55] Request 27625/27722: Yuba City → Madera (attempt 1)
# [2025-07-10 01:46:55]   ✅ Success: 305,018 meters, 10838s
# [2025-07-10 01:46:56] Request 27626/27722: Yuba City → Manteca (attempt 1)
# [2025-07-10 01:46:56]   ✅ Success: 162,626 meters, 6221s
# [2025-07-10 01:46:56] Request 27627/27722: Yuba City → Mariposa (attempt 1)
# [2025-07-10 01:46:57]   ✅ Success: 310,831 meters, 11628s
# [2025-07-10 01:46:57] Request 27628/27722: Yuba City → Mendota (attempt 1)
# [2025-07-10 01:46:57]   ✅ Success: 326,447 meters, 11549s
# [2025-07-10 01:46:58] Request 27629/27722: Yuba City → Merced (attempt 1)
# [2025-07-10 01:46:58]   ✅ Success: 248,589 meters, 8878s
# [2025-07-10 01:46:58] Request 27630/27722: Yuba City → Modesto (attempt 1)
# [2025-07-10 01:46:59]   ✅ Success: 189,486 meters, 7057s
# [2025-07-10 01:46:59] Progress saved: 27630 completed, 0 failed, 92 remaining
# [2025-07-10 01:46:59] Request 27631/27722: Yuba City → Montebello (attempt 1)
# [2025-07-10 01:47:00]   ✅ Success: 698,396 meters, 23980s
# [2025-07-10 01:47:00] Request 27632/27722: Yuba City → Mt Shasta (attempt 1)
# [2025-07-10 01:47:00]   ✅ Success: 280,826 meters, 10614s
# [2025-07-10 01:47:01] Request 27633/27722: Yuba City → Napa (attempt 1)
# [2025-07-10 01:47:01]   ✅ Success: 138,737 meters, 5559s
# [2025-07-10 01:47:02] Request 27634/27722: Yuba City → Needles (attempt 1)
# [2025-07-10 01:47:02]   ✅ Success: 953,985 meters, 32544s
# [2025-07-10 01:47:03] Request 27635/27722: Yuba City → Newhall (attempt 1)
# [2025-07-10 01:47:03]   ✅ Success: 636,771 meters, 21595s
# [2025-07-10 01:47:03] Request 27636/27722: Yuba City → Norco (attempt 1)
# [2025-07-10 01:47:04]   ✅ Success: 758,747 meters, 25847s
# [2025-07-10 01:47:04] Request 27637/27722: Yuba City → Novato (attempt 1)
# [2025-07-10 01:47:04]   ✅ Success: 173,805 meters, 6971s
# [2025-07-10 01:47:05] Request 27638/27722: Yuba City → Oakland (attempt 1)
# [2025-07-10 01:47:05]   ✅ Success: 179,325 meters, 6967s
# [2025-07-10 01:47:06] Request 27639/27722: Yuba City → Oceanside (attempt 1)
# [2025-07-10 01:47:06]   ✅ Success: 836,279 meters, 28188s
# [2025-07-10 01:47:06] Request 27640/27722: Yuba City → Oroville (attempt 1)
# [2025-07-10 01:47:07]   ✅ Success: 48,411 meters, 2242s
# [2025-07-10 01:47:07] Progress saved: 27640 completed, 0 failed, 82 remaining
# [2025-07-10 01:47:07] Request 27641/27722: Yuba City → Oxnard (attempt 1)
# [2025-07-10 01:47:08]   ✅ Success: 700,570 meters, 24662s
# [2025-07-10 01:47:08] Request 27642/27722: Yuba City → Palm Desert (attempt 1)
# [2025-07-10 01:47:08]   ✅ Success: 872,478 meters, 29366s
# [2025-07-10 01:47:09] Request 27643/27722: Yuba City → Palm Springs (attempt 1)
# [2025-07-10 01:47:09]   ✅ Success: 856,103 meters, 28994s
# [2025-07-10 01:47:10] Request 27644/27722: Yuba City → Pasadena (attempt 1)
# [2025-07-10 01:47:10]   ✅ Success: 692,407 meters, 23404s
# [2025-07-10 01:47:11] Request 27645/27722: Yuba City → Paso Robles (attempt 1)
# [2025-07-10 01:47:11]   ✅ Success: 492,465 meters, 17092s
# [2025-07-10 01:47:11] Request 27646/27722: Yuba City → Petaluma (attempt 1)
# [2025-07-10 01:47:12]   ✅ Success: 181,597 meters, 7509s
# [2025-07-10 01:47:12] Request 27647/27722: Yuba City → Pittsburg (attempt 1)
# [2025-07-10 01:47:12]   ✅ Success: 172,325 meters, 6821s
# [2025-07-10 01:47:13] Request 27648/27722: Yuba City → Placerville (attempt 1)
# [2025-07-10 01:47:13]   ✅ Success: 136,891 meters, 5088s
# [2025-07-10 01:47:14] Request 27649/27722: Yuba City → Pleasanton (attempt 1)
# [2025-07-10 01:47:14]   ✅ Success: 193,251 meters, 7450s
# [2025-07-10 01:47:15] Request 27650/27722: Yuba City → Pomona (attempt 1)
# [2025-07-10 01:47:15]   ✅ Success: 729,262 meters, 25019s
# [2025-07-10 01:47:15] Progress saved: 27650 completed, 0 failed, 72 remaining
# [2025-07-10 01:47:16] Request 27651/27722: Yuba City → Porterville (attempt 1)
# [2025-07-10 01:47:16]   ✅ Success: 450,173 meters, 16237s
# [2025-07-10 01:47:16] Request 27652/27722: Yuba City → Poway (attempt 1)
# [2025-07-10 01:47:17]   ✅ Success: 879,269 meters, 29987s
# [2025-07-10 01:47:17] Request 27653/27722: Yuba City → Quincy (attempt 1)
# [2025-07-10 01:47:18]   ✅ Success: 174,372 meters, 7872s
# [2025-07-10 01:47:18] Request 27654/27722: Yuba City → Rancho Cucamonga (attempt 1)
# [2025-07-10 01:47:18]   ✅ Success: 740,714 meters, 25286s
# [2025-07-10 01:47:19] Request 27655/27722: Yuba City → Rancho San Diego Industry Business Center (attempt 1)
# [2025-07-10 01:47:19]   ✅ Success: 903,176 meters, 30677s
# [2025-07-10 01:47:20] Request 27656/27722: Yuba City → Red Bluff (attempt 1)
# [2025-07-10 01:47:20]   ✅ Success: 137,903 meters, 5717s
# [2025-07-10 01:47:20] Request 27657/27722: Yuba City → Redding (attempt 1)
# [2025-07-10 01:47:21]   ✅ Success: 184,337 meters, 7287s
# [2025-07-10 01:47:21] Request 27658/27722: Yuba City → Redlands (attempt 1)
# [2025-07-10 01:47:22]   ✅ Success: 779,362 meters, 26381s
# [2025-07-10 01:47:22] Request 27659/27722: Yuba City → Redwood City (attempt 1)
# [2025-07-10 01:47:22]   ✅ Success: 226,754 meters, 8896s
# [2025-07-10 01:47:23] Request 27660/27722: Yuba City → Reedley (attempt 1)
# [2025-07-10 01:47:23]   ✅ Success: 377,808 meters, 13634s
# [2025-07-10 01:47:23] Progress saved: 27660 completed, 0 failed, 62 remaining
# [2025-07-10 01:47:24] Request 27661/27722: Yuba City → Ridgecrest (attempt 1)
# [2025-07-10 01:47:24]   ✅ Success: 692,985 meters, 23870s
# [2025-07-10 01:47:25] Request 27662/27722: Yuba City → Riverside (attempt 1)
# [2025-07-10 01:47:25]   ✅ Success: 772,896 meters, 26374s
# [2025-07-10 01:47:25] Request 27663/27722: Yuba City → Riverside East (attempt 1)
# [2025-07-10 01:47:26]   ✅ Success: 775,853 meters, 26407s
# [2025-07-10 01:47:26] Request 27664/27722: Yuba City → Rocklin (attempt 1)
# [2025-07-10 01:47:26]   ✅ Success: 65,508 meters, 2981s
# [2025-07-10 01:47:27] Request 27665/27722: Yuba City → Roseville (attempt 1)
# [2025-07-10 01:47:27]   ✅ Success: 59,302 meters, 2781s
# [2025-07-10 01:47:28] Request 27666/27722: Yuba City → Sacramento (attempt 1)
# [2025-07-10 01:47:28]   ✅ Success: 74,799 meters, 3117s
# [2025-07-10 01:47:28] Request 27667/27722: Yuba City → Sacramento South (attempt 1)
# [2025-07-10 01:47:28]   ✅ Success: 82,593 meters, 3195s
# [2025-07-10 01:47:29] Request 27668/27722: Yuba City → Salinas (attempt 1)
# [2025-07-10 01:47:29]   ✅ Success: 327,079 meters, 11935s
# [2025-07-10 01:47:30] Request 27669/27722: Yuba City → San Andreas (attempt 1)
# [2025-07-10 01:47:30]   ✅ Success: 176,579 meters, 6975s
# [2025-07-10 01:47:30] Request 27670/27722: Yuba City → San Bernardino (attempt 1)
# [2025-07-10 01:47:31]   ✅ Success: 769,202 meters, 26012s
# [2025-07-10 01:47:31] Progress saved: 27670 completed, 0 failed, 52 remaining
# [2025-07-10 01:47:31] Request 27671/27722: Yuba City → San Clemente (attempt 1)
# [2025-07-10 01:47:32]   ✅ Success: 789,668 meters, 26790s
# [2025-07-10 01:47:32] Request 27672/27722: Yuba City → San Diego (attempt 1)
# [2025-07-10 01:47:33]   ✅ Success: 883,825 meters, 29741s
# [2025-07-10 01:47:33] Request 27673/27722: Yuba City → San Diego Clairemont (attempt 1)
# [2025-07-10 01:47:33]   ✅ Success: 874,962 meters, 29585s
# [2025-07-10 01:47:34] Request 27674/27722: Yuba City → San Francisco (attempt 1)
# [2025-07-10 01:47:34]   ✅ Success: 190,809 meters, 7848s
# [2025-07-10 01:47:35] Request 27675/27722: Yuba City → San Jose (attempt 1)
# [2025-07-10 01:47:35]   ✅ Success: 243,831 meters, 9223s
# [2025-07-10 01:47:35] Request 27676/27722: Yuba City → San Luis Obispo (attempt 1)
# [2025-07-10 01:47:36]   ✅ Success: 542,071 meters, 18699s
# [2025-07-10 01:47:36] Request 27677/27722: Yuba City → San Marcos (attempt 1)
# [2025-07-10 01:47:37]   ✅ Success: 854,413 meters, 28929s
# [2025-07-10 01:47:37] Request 27678/27722: Yuba City → San Mateo (attempt 1)
# [2025-07-10 01:47:38]   ✅ Success: 213,676 meters, 8307s
# [2025-07-10 01:47:38] Request 27679/27722: Yuba City → San Pedro (attempt 1)
# [2025-07-10 01:47:38]   ✅ Success: 717,378 meters, 24290s
# [2025-07-10 01:47:39] Request 27680/27722: Yuba City → San Ysidro (attempt 1)
# [2025-07-10 01:47:39]   ✅ Success: 910,228 meters, 30711s
# [2025-07-10 01:47:39] Progress saved: 27680 completed, 0 failed, 42 remaining
# [2025-07-10 01:47:40] Request 27681/27722: Yuba City → Santa Ana (attempt 1)
# [2025-07-10 01:47:40]   ✅ Success: 735,039 meters, 25518s
# [2025-07-10 01:47:41] Request 27682/27722: Yuba City → Santa Barbara (attempt 1)
# [2025-07-10 01:47:41]   ✅ Success: 688,172 meters, 24028s
# [2025-07-10 01:47:42] Request 27683/27722: Yuba City → Santa Clara (attempt 1)
# [2025-07-10 01:47:42]   ✅ Success: 240,328 meters, 9524s
# [2025-07-10 01:47:42] Request 27684/27722: Yuba City → Santa Monica (attempt 1)
# [2025-07-10 01:47:43]   ✅ Success: 681,951 meters, 23103s
# [2025-07-10 01:47:43] Request 27685/27722: Yuba City → Santa Paula (attempt 1)
# [2025-07-10 01:47:43]   ✅ Success: 671,999 meters, 22866s
# [2025-07-10 01:47:44] Request 27686/27722: Yuba City → Santa Rosa (attempt 1)
# [2025-07-10 01:47:44]   ✅ Success: 204,758 meters, 8114s
# [2025-07-10 01:47:45] Request 27687/27722: Yuba City → Santa Teresa (attempt 1)
# [2025-07-10 01:47:45]   ✅ Success: 252,463 meters, 9520s
# [2025-07-10 01:47:45] Request 27688/27722: Yuba City → Seaside (attempt 1)
# [2025-07-10 01:47:45]   ✅ Success: 344,473 meters, 12554s
# [2025-07-10 01:47:46] Request 27689/27722: Yuba City → Shafter (attempt 1)
# [2025-07-10 01:47:46]   ✅ Success: 496,099 meters, 16961s
# [2025-07-10 01:47:47] Request 27690/27722: Yuba City → Simi Valley (attempt 1)
# [2025-07-10 01:47:47]   ✅ Success: 675,401 meters, 22774s
# [2025-07-10 01:47:47] Progress saved: 27690 completed, 0 failed, 32 remaining
# [2025-07-10 01:47:48] Request 27691/27722: Yuba City → Sonora (attempt 1)
# [2025-07-10 01:47:48]   ✅ Success: 222,068 meters, 9422s
# [2025-07-10 01:47:48] Request 27692/27722: Yuba City → South Lake Tahoe (attempt 1)
# [2025-07-10 01:47:50]   ✅ Success: 233,320 meters, 9281s
# [2025-07-10 01:47:50] Request 27693/27722: Yuba City → Stockton (attempt 1)
# [2025-07-10 01:47:50]   ✅ Success: 144,486 meters, 5370s
# [2025-07-10 01:47:51] Request 27694/27722: Yuba City → Susanville (attempt 1)
# [2025-07-10 01:47:51]   ✅ Success: 233,288 meters, 10320s
# [2025-07-10 01:47:51] Request 27695/27722: Yuba City → Taft (attempt 1)
# [2025-07-10 01:47:52]   ✅ Success: 517,913 meters, 17829s
# [2025-07-10 01:47:52] Request 27696/27722: Yuba City → Temecula (attempt 1)
# [2025-07-10 01:47:52]   ✅ Success: 816,980 meters, 27658s
# [2025-07-10 01:47:53] Request 27697/27722: Yuba City → Thousand Oaks (attempt 1)
# [2025-07-10 01:47:53]   ✅ Success: 698,580 meters, 23509s
# [2025-07-10 01:47:54] Request 27698/27722: Yuba City → Torrance (attempt 1)
# [2025-07-10 01:47:54]   ✅ Success: 706,346 meters, 24118s
# [2025-07-10 01:47:55] Request 27699/27722: Yuba City → Tracy (attempt 1)
# [2025-07-10 01:47:55]   ✅ Success: 177,248 meters, 6359s
# [2025-07-10 01:47:55] Request 27700/27722: Yuba City → Truckee (attempt 1)
# [2025-07-10 01:47:55]   ✅ Success: 148,157 meters, 6397s
# [2025-07-10 01:47:56] Progress saved: 27700 completed, 0 failed, 22 remaining
# [2025-07-10 01:47:56] Request 27701/27722: Yuba City → Tulare (attempt 1)
# [2025-07-10 01:47:57]   ✅ Success: 410,560 meters, 14328s
# [2025-07-10 01:47:58] Request 27702/27722: Yuba City → Tulelake (attempt 1)
# [2025-07-10 01:47:58]   ✅ Success: 418,414 meters, 15768s
# [2025-07-10 01:47:59] Request 27703/27722: Yuba City → Turlock (attempt 1)
# [2025-07-10 01:47:59]   ✅ Success: 208,981 meters, 7749s
# [2025-07-10 01:47:59] Request 27704/27722: Yuba City → Twentynine Palms (attempt 1)
# [2025-07-10 01:48:00]   ✅ Success: 873,949 meters, 30804s
# [2025-07-10 01:48:00] Request 27705/27722: Yuba City → Ukiah (attempt 1)
# [2025-07-10 01:48:00]   ✅ Success: 189,110 meters, 8073s
# [2025-07-10 01:48:01] Request 27706/27722: Yuba City → Vacaville (attempt 1)
# [2025-07-10 01:48:01]   ✅ Success: 100,844 meters, 4265s
# [2025-07-10 01:48:02] Request 27707/27722: Yuba City → Vallejo (attempt 1)
# [2025-07-10 01:48:02]   ✅ Success: 139,420 meters, 5662s
# [2025-07-10 01:48:02] Request 27708/27722: Yuba City → Van Nuys (attempt 1)
# [2025-07-10 01:48:03]   ✅ Success: 660,968 meters, 22328s
# [2025-07-10 01:48:03] Request 27709/27722: Yuba City → Ventura (attempt 1)
# [2025-07-10 01:48:03]   ✅ Success: 692,144 meters, 23626s
# [2025-07-10 01:48:04] Request 27710/27722: Yuba City → Victorville (attempt 1)
# [2025-07-10 01:48:04]   ✅ Success: 730,841 meters, 25693s
# [2025-07-10 01:48:04] Progress saved: 27710 completed, 0 failed, 12 remaining
# [2025-07-10 01:48:05] Request 27711/27722: Yuba City → Visalia (attempt 1)
# [2025-07-10 01:48:05]   ✅ Success: 409,365 meters, 14270s
# [2025-07-10 01:48:06] Request 27712/27722: Yuba City → Watsonville (attempt 1)
# [2025-07-10 01:48:06]   ✅ Success: 307,635 meters, 11855s
# [2025-07-10 01:48:06] Request 27713/27722: Yuba City → Weaverville (attempt 1)
# [2025-07-10 01:48:06]   ✅ Success: 254,783 meters, 10201s
# [2025-07-10 01:48:07] Request 27714/27722: Yuba City → West Covina (attempt 1)
# [2025-07-10 01:48:07]   ✅ Success: 712,736 meters, 24496s
# [2025-07-10 01:48:08] Request 27715/27722: Yuba City → West Hollywood (attempt 1)
# [2025-07-10 01:48:08]   ✅ Success: 675,189 meters, 23198s
# [2025-07-10 01:48:09] Request 27716/27722: Yuba City → West Sacramento Commercial Drive Test Center (attempt 1)
# [2025-07-10 01:48:09]   ✅ Success: 70,510 meters, 2781s
# [2025-07-10 01:48:09] Request 27717/27722: Yuba City → Westminster (attempt 1)
# [2025-07-10 01:48:10]   ✅ Success: 737,189 meters, 25095s
# [2025-07-10 01:48:10] Request 27718/27722: Yuba City → Whittier (attempt 1)
# [2025-07-10 01:48:11]   ✅ Success: 707,144 meters, 24816s
# [2025-07-10 01:48:11] Request 27719/27722: Yuba City → Willows (attempt 1)
# [2025-07-10 01:48:11]   ✅ Success: 86,835 meters, 3574s
# [2025-07-10 01:48:12] Request 27720/27722: Yuba City → Winnetka (attempt 1)
# [2025-07-10 01:48:12]   ✅ Success: 669,405 meters, 22989s
# [2025-07-10 01:48:12] Progress saved: 27720 completed, 0 failed, 2 remaining
# [2025-07-10 01:48:13] Request 27721/27722: Yuba City → Woodland (attempt 1)
# [2025-07-10 01:48:13]   ✅ Success: 60,507 meters, 2865s
# [2025-07-10 01:48:13] Request 27722/27722: Yuba City → Yreka (attempt 1)
# [2025-07-10 01:48:14]   ✅ Success: 336,950 meters, 12535s
# [2025-07-10 01:48:14] Progress saved: 27722 completed, 0 failed, 0 remaining
# [2025-07-10 01:48:14] Progress file cleaned up (processing complete)
# [2025-07-10 01:48:14] Results saved to dmv_office_route_distances.json
# [2025-07-10 01:48:14] Total routes calculated: 27722
# [2025-07-10 01:48:14] Failed routes: 0
# [2025-07-10 01:48:14] Success rate: 27722/27722 (100.0%)
# [2025-07-10 01:48:14] Sample result:
# [2025-07-10 01:48:14]   Alturas → Arleta
# [2025-07-10 01:48:14]   Distance: 1,000,148 meters
# [2025-07-10 01:48:14]   Duration: 36018s
# [2025-07-10 01:48:14] Processing complete!

# %% [raw]
# # Programming Concepts Explained for Math Students
#
# This notebook uses several programming concepts that might be unfamiliar to math students. Here's a detailed explanation of the key concepts:
#
# ## Data Structures
#
# ### Lists
# - **What it is**: An ordered collection of items, like a mathematical sequence
# - **Math analogy**: Similar to a vector or tuple: [item₁, item₂, item₃, ...]
# - **Example**: `[1, 2, 3]` or `['Apple', 'Banana', 'Cherry']`
# - **Operations**:
#   - `list.append(item)`: Add item to end
#   - `list[0]`: Get first item (0-indexed)
#   - `list[:5]`: Get first 5 items (slicing)
#   - `len(list)`: Get number of items
#
# ### Dictionaries
# - **What it is**: A collection of key-value pairs, like a function mapping
# - **Math analogy**: Similar to a function f: domain → codomain
# - **Example**: `{'name': 'John', 'age': 25, 'city': 'San Francisco'}`
# - **Operations**:
#   - `dict['key']`: Get value for key
#   - `dict.get('key')`: Safely get value (returns None if key doesn't exist)
#
# ## API (Application Programming Interface)
#
# ### What is an API?
# - **Definition**: A way for programs to communicate with each other
# - **Analogy**: Like a restaurant menu - you request something specific, and the kitchen (server) prepares it
# - **Google Routes API**: We send location coordinates, Google returns driving directions
#
# ### HTTP Requests
# - **GET**: "Please give me information" (like asking for a webpage)
# - **POST**: "Here's some data, please process it" (like submitting a form)
# - **Status Codes**:
#   - 200: Success ("OK")
#   - 400: Bad request ("You asked for something wrong")
#   - 401: Unauthorized ("You don't have permission")
#   - 500: Server error ("Something went wrong on Google's side")
#
# ## JSON (JavaScript Object Notation)
#
# ### What is JSON?
# - **Purpose**: A standard way to structure data for communication between programs
# - **Format**: Similar to Python dictionaries, but stricter formatting rules
# - **Example**:
# ```json
# {
#   "name": "John Doe",
#   "coordinates": {
#     "latitude": 37.7749,
#     "longitude": -122.4194
#   },
#   "scores": [85, 92, 78]
# }
# ```
#
# ## Mathematical Concepts Used
#
# ### Permutations
# - **Definition**: Arrangements where order matters
# - **Formula**: P(n,r) = n!/(n-r)!
# - **In our code**: `itertools.permutations(offices, 2)` creates all ordered pairs
# - **Example**: With offices A, B, C, we get: (A→B), (A→C), (B→A), (B→C), (C→A), (C→B)
#
# ### Combinations (not used here, but related)
# - **Definition**: Selections where order doesn't matter
# - **Formula**: C(n,r) = n!/(r!(n-r)!)
# - **If we used this**: We'd get half as many routes (A↔B same as B↔A)
#
# ## Error Handling
#
# ### Why it's important
# - **Networks can fail**: Internet connection issues
# - **APIs can be down**: Google's servers might be temporarily unavailable
# - **Data can be malformed**: Unexpected response formats
#
# ### How we handle it
# - **Check status codes**: `if response.status_code == 200:`
# - **Validate data exists**: `if "routes" in response_data:`
# - **Safe value extraction**: `distance = first_route.get("distanceMeters")`
#
# ## File Operations
#
# ### Writing to files
# - **Purpose**: Save results for later use or analysis
# - **JSON format**: Human-readable and parseable by other programs
# - **The `with` statement**: Automatically closes files when done (prevents data corruption)
#
# ## Cost Considerations
#
# ### API Rate Limits
# - **Google's limits**: Number of requests per minute/day
# - **Our approach**: Process requests sequentially to avoid overwhelming the API
#
# ### Financial Cost
# - **Current test**: 6 requests ≈ $0.03
# - **Full analysis**: 27,722 requests ≈ $138.61
# - **Optimization strategies**:
#   - Use combinations instead of permutations (halve the cost)
#   - Filter by distance (only calculate routes under certain distance)
#   - Use caching (save results to avoid re-calculating)
#
# ## Next Steps for Analysis
#
# Once you have the route data, you can:
# 1. **Calculate statistics**: Average distance, shortest/longest routes
# 2. **Create visualizations**: Plot routes on maps, create histograms
# 3. **Optimization problems**: Find optimal office locations, minimize total travel time
# 4. **Network analysis**: Treat offices as nodes in a graph, analyze connectivity
